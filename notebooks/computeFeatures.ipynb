# %%
import pandas as pd
from collections import OrderedDict
import numpy as np
import json
import time
from sklearn.preprocessing import OneHotEncoder

import sys
sys.path.append('../python')
import userHistorial as uh
import ELO as elo
import timeLimitEvents as timeLimits

# %%
# Dataframe with all the events
dataEvents = pd.read_csv('E:/Documentos/PCEO/5/Informatica/TFG/datos/anonamyze_all_data_collection_v2.csv', sep=";")

# %%
# Dictionary with the average complete time of every puzzle
tiemposPuzzles = pd.read_csv('E:/Documentos/PCEO/5/Informatica/TFG/scripts/TFG-Informatica/Outputs/avgTimeByPuzzleOutput.csv', sep=";")

# %%
# Dictionary with the ELO difficulty of every puzzle
dict_elo_puzzles = {
    'Sandbox': 0.0,
    '1. One Box': 0.0,
    '2. Separated Boxes': 0.12,
    '3. Rotate a Pyramid': 0.23,
    '4. Match Silhouettes': 0.42,
    '9. Scaling Round Objects': 0.58,
    '8. Combine 2 Ramps': 0.57,
    'Sugar Cones': 0.90,
    'Square Cross-Sections': 0.99,
    'Bird Fez': 1.77,
    'Pi Henge': 1.26,
    '45-Degree Rotations': 0.78,
    'Pyramids are Strange': 1.29,
    'Boxes Obscure Spheres': 1.91,
    'Object Limits': 1.62,
    'Tetromino': 1.74,
    'Angled Silhouette': 1.35,
    'Stranger Shapes': 1.7,
    'Tall and Small': 1.73,
    '5. Removing Objects': 0.48,
    '6. Stretch a Ramp': 0.42,
    '7. Max 2 Boxes': 0.6,
    'Ramp Up and Can It': 1.73,
    'More Than Meets Your Eye': 1.2,
    'Bear Market': 3.0,
    'Not Bird': 2.13,
    'Warm Up': 0.6,
    'Unnecessary': 1.74,
    'Zzz': 1.81,
    'Bull Market': 2.98,
    'Few Clues': 1.93,
    'Orange Dance': 2.37
}

# %%
# Every puzzle difficulty
difficultyMapping = ['Sandbox~0.000001','1. One Box~0.000002', '2. Separated Boxes~0.111127', '3. Rotate a Pyramid~0.083447', '4. Match Silhouettes~0.061887', '5. Removing Objects~0.106021', '6. Stretch a Ramp~0.107035', '7. Max 2 Boxes~0.078039', '8. Combine 2 Ramps~0.068608', '9. Scaling Round Objects~0.128647',
                     'Square Cross-Sections~0.199714', 'Bird Fez~0.156674', 'Pi Henge~0.067346', '45-Degree Rotations~0.096715',  'Pyramids are Strange~0.179600', 'Boxes Obscure Spheres~0.266198', 'Object Limits~0.257177', 'Not Bird~0.260197', 'Angled Silhouette~0.147673',
                     'Warm Up~0.183971','Tetromino~0.226869', 'Stranger Shapes~0.283971', 'Sugar Cones~0.085909', 'Tall and Small~0.266869', 'Ramp Up and Can It~0.206271', 'More Than Meets Your Eye~0.192319', 'Unnecessary~0.76', 'Zzz~0.234035', 'Bull Market~0.358579', 'Few Clues~0.324041', 'Orange Dance~0.647731', 'Bear Market~1.000000']


# Dictionary with the difficulty of every puzzle
difficultyPuzzles = dict()

for puzzle in difficultyMapping:
    desc = puzzle.split("~")
    difficultyPuzzles[desc[0]] = float(desc[1])

# %%
def computeFeatures(dataEvents,percentil=1, user_objective='all', group_objective = 'all'):

    # Guardar el instante inicial
    inicio = time.time()



    dataEvents['time'] = pd.to_datetime(dataEvents['time'])

    #iterates in the groups and users of the data
    dataEvents['user'] = [json.loads(x)['user'] if 'user' in json.loads(x).keys() else '' for x in dataEvents['data']]
    dataEvents['group'] = [json.loads(x)['group'] if 'group' in json.loads(x).keys() else '' for x in
                           dataEvents['data']]
    dataEvents['task_id'] = [json.loads(x)['task_id'] if 'task_id' in json.loads(x).keys() else '' for x in
                             dataEvents['data']]

    # removing those rows where we dont have a group and a user that is not guest
    dataEvents = dataEvents[
        ((dataEvents['group'] != '') & (dataEvents['user'] != '') & (dataEvents['user'] != 'guest'))]
    dataEvents['group_user_id'] = dataEvents['group'] + '~' + dataEvents['user']
    dataEvents['group_user_task_id'] = dataEvents['group'] + '~' + dataEvents['user'] + '~' + dataEvents['task_id']



    # filtering to only take the user passed as argument
    if(group_objective != 'all'):
        dataEvents = dataEvents[dataEvents['group'].isin(group_objective)]

    dataEvents = dataEvents.sort_values('time')

    #copia
    copia = dataEvents.copy()


    # the data is grouped by the necessary variables
    activity_by_user = dataEvents.groupby(['group_user_id']).agg({'id': 'count',
                                                                  'type': 'nunique'}).reset_index().rename(columns={'id': 'events',
                                                                                        'type': 'different_events'})

    typeEvents = ['ws-snapshot', 'ws-paint', 'ws-rotate_view', 'ws-move_shape', 'ws-rotate_shape', 'ws-scale_shape',
                  'ws-create_shape', 'ws-delete_shape', 'ws-undo_action', 'ws-redo_action', 'ws-check_solution']
    manipulationTypeEvents = ['ws-move_shape', 'ws-rotate_shape', 'ws-scale_shape', 'ws-create_shape',
                              'ws-delete_shape']

    #initialize the metrics
    activity_by_user['completed'] = np.nan
    activity_by_user['active_time'] = np.nan
    activity_by_user['n_events'] = np.nan
    activity_by_user['timestamp'] = np.nan

    for event in typeEvents:
        activity_by_user[event] = 0
#----------------------------------------------------------------------------------------------------------------------------------
    #initialize the data structures

    puzzleEvents = dict() #Diccionario que guarda para cada intento (alumno,puzzle,nintento) el número de eventos

    timePuzzle = dict() #Diccionario que guarda para cada intento el tiempo activo

    globalTypesEvents = dict() #Diccionario que guarda para cada intento el número de eventos de cada tipo

    n_attempts = dict() #Diccionario que guarda para cada el número de intentos

    completados = dict() #Diccionario que guarda para cada intento si se completó

    timestamp = dict() #Diccionario que guarda para cada intento el timestamp inicial

    percentilAtt = dict()
    percentilTime = dict() #Diccionarios que guardan un 90 para cada intento (creo)
    percentilAttValue = 90
    percentilTimeValue = 90

    breaksPuzzle = dict() #Diccionario que guarda para cada intento el número de breaks ( parones de 15 segundos )

    cumAttempts = OrderedDict() #Diccionario que guarda para cada intento, que número de intento gloabal es


    userCumAttempts = OrderedDict() #Diccionario que guarda para cada alumno cuantos intentos en total ha hecho


    prevReg = dict() #Diccionario que almacena para cada dupla alumno-puzzle, si se ha intentado anteriormente

    actualAtt = 0 #Variable global que lleva el contador de intentos global

    idComplete = dict() #Diccionario que guarda para cada intento si se finalizó

    attemptsAux = dict() #Doble diccionario que guarda para cada usuario y para cada puzzle el numero de intentos

    contCheckSol = dict() #Diccionario que guarda para cada intento el número de submits

    bestSubmit = dict() #Diccionario que guarda el mejor submit de cada intento

    manipulationEvents = dict() #Diccionario que guarda para cada intento el número de eventos de manipulacion

    userManipulationEvents = dict() #Creo que actualmente no se utiliza

    contManipulation = 0

    timeFirstCheck = dict() #Diccionario que guarda para cada intento el timestamp del primer submit

    timeSubExit = dict() #Diccionario que guarda para cada intento, el tiempo que ha pasado entre el primer submit y el exit

    timeCheckActual = dict() #Diccionario que guarda para cada intento el timestamp del último check

    timeBetweenSub = dict() #Diccionario que guarda para cada intento la media de tiempo entre cada submit
#---------------------------------------------------------------------------------------------------------------------------------
    for user in dataEvents['group_user_id'].unique():

        # Computing active time
        previousEvent = None
        theresHoldActivity = 60
        tiempoPercentil = 0

        user_events = dataEvents[dataEvents['group_user_id'] == user] #eventos del usuario
        user_puzzle_key = None
        userParc = None
        task_id = None
        initialTime = None
        prev_id = 1

        for enum, event in user_events.iterrows():

            # If it is the first event
            if (previousEvent is None):
                previousEvent = event
                continue

            if (event['type'] in ['ws-start_level']):

                #create id: group+user+task_id
                task_id = json.loads(event['data'])['task_id']

                if (user_puzzle_key not in timeSubExit.keys()):
                    timeSubExit[user_puzzle_key] = str(0)
                    timeBetweenSub[user_puzzle_key] = str(0)

                if (event['user'] not in userCumAttempts.keys()):
                    userCumAttempts[event['user']] = 0
                    actualAtt = 0
                    attemptsAux[event['user']] = dict()
                    timeCheckActual[event['user']] = 0

                if (event['user'] not in userManipulationEvents.keys()):
                    userManipulationEvents[event['user']] = 0


                if (task_id not in attemptsAux[event['user']].keys()): attemptsAux[event['user']][task_id] = 0

                user_puzzle_key = event['group'] + '~' + event[
                    'user'] + '~' + task_id  # + '~' + str(n_attempts[prev_id])
                if (user_puzzle_key not in prevReg.keys()):

                    prevReg[user_puzzle_key] = 1
                    user_puzzle_key = event['group'] + '~' + event['user'] + '~' + task_id + '~' + '1'
                    n_attempts[user_puzzle_key] = 1
                    attemptsAux[event['user']][task_id] = n_attempts[user_puzzle_key]

                else:

                    user_puzzle_key = event['group'] + '~' + event['user'] + '~' + task_id + '~' + str(
                        attemptsAux[event['user']][task_id])
                    n_attempts[user_puzzle_key] = attemptsAux[event['user']][task_id]

                key_split = user_puzzle_key.split('~')
                puzzleParc = key_split[2]
                userParc = key_split[1]

                tiemposPuzzle = tiemposPuzzles[tiemposPuzzles['puzzle']==puzzleParc].reset_index()
                if not tiemposPuzzle.empty:
                    tiempoPercentil =  round(tiemposPuzzle.loc[0,'avg_complete_time']*0.25*percentil,2)

                if (user_puzzle_key not in idComplete.keys()): idComplete[user_puzzle_key] = 0

                if (task_id not in attemptsAux[userParc].keys()): attemptsAux[userParc][task_id] = 0
                if (user_puzzle_key not in cumAttempts.keys()): cumAttempts[user_puzzle_key] = 1

                # initialize if the id is new
                if (user_puzzle_key not in puzzleEvents.keys()):

                    breaksPuzzle[user_puzzle_key] = 0
                    timestamp[user_puzzle_key] = 0
                    percentilAtt[user_puzzle_key] = percentilAttValue
                    percentilTime[user_puzzle_key] = percentilTimeValue
                    completados[user_puzzle_key] = 0
                    puzzleEvents[user_puzzle_key] = 1
                    timePuzzle[user_puzzle_key] = 0
                    contCheckSol[user_puzzle_key] = 0
                    bestSubmit[user_puzzle_key] = 0
                    manipulationEvents[user_puzzle_key] = 0
                    timeFirstCheck[user_puzzle_key] = 0

                    globalTypesEvents[user_puzzle_key] = dict()
                    for ev in typeEvents:
                        globalTypesEvents[user_puzzle_key][ev] = 0

                #timestamp
                if (event['type'] in 'ws-start_level'):
                    timestamp[user_puzzle_key] = event['time']

            # the event is not final event
            if (event['type'] not in ['ws-exit_to_menu', 'ws-disconnect', 'ws-create_user', 'ws-login_user']):

                #calculate the duration of the event
                delta_seconds = (event['time'] - previousEvent['time']).total_seconds()

                if ((delta_seconds < theresHoldActivity)):
                    timePuzzle[user_puzzle_key] += delta_seconds



                if (event['type'] in ['ws-puzzle_complete']): completados[user_puzzle_key] = 1



                if round((timePuzzle[user_puzzle_key]/60),2) < tiempoPercentil:

                    puzzleEvents[user_puzzle_key] += 1

                    #breaks
                    if ((delta_seconds > 15)):
                        breaksPuzzle[user_puzzle_key] += 1

                    #update event counters by type
                    if (event['type'] in typeEvents):
                        globalTypesEvents[user_puzzle_key][event['type']] += 1

                    if (globalTypesEvents[user_puzzle_key]['ws-check_solution'] == 1): timeFirstCheck[user_puzzle_key] = \
                        event['time']

                    if (event['type'] in manipulationTypeEvents):
                        manipulationEvents[user_puzzle_key] += 1

                    if (event['type'] == 'ws-check_solution'):
                        timeCheckActual[event['user']] = event['time']
                        contCheckSol[user_puzzle_key] += 1
                        dict_views = json.loads(event['data'])['correct']
                        corr = 0
                        for key in dict_views:
                            if key == True:
                                corr += 1
                        percentage_aux = (corr / len(dict_views))*100
                        if percentage_aux > bestSubmit[user_puzzle_key]:
                            bestSubmit[user_puzzle_key] = round(percentage_aux,2)






                previousEvent = event



            # the puzzle ends
            if (event['type'] in ['ws-exit_to_menu', 'ws-disconnect']):

                idComplete[user_puzzle_key] = 1

                #calculate the duration of the event
                delta_seconds = (event['time'] - previousEvent['time']).total_seconds()
                if ((delta_seconds < theresHoldActivity)):
                    timePuzzle[user_puzzle_key] += delta_seconds



                if round((timePuzzle[user_puzzle_key]/60),2) < tiempoPercentil:

                    puzzleEvents[user_puzzle_key] += 1

                    #breaks
                    if ((delta_seconds > 15)):
                        breaksPuzzle[user_puzzle_key] += 1


                if (completados[user_puzzle_key] == 0 and globalTypesEvents[user_puzzle_key]['ws-check_solution'] > 0):
                    timeSubExit[user_puzzle_key] = str(
                        round((event['time'] - timeFirstCheck[user_puzzle_key]).total_seconds(), 2))
                else:
                    timeSubExit[user_puzzle_key] = 'NA'

                if (globalTypesEvents[user_puzzle_key]['ws-check_solution'] == 0):
                    timeBetweenSub[user_puzzle_key] = 'NA'
                else:
                    timeBetweenSub[user_puzzle_key] = str(round(((timeCheckActual[event['user']] - timestamp[
                        user_puzzle_key]) / globalTypesEvents[user_puzzle_key]['ws-check_solution']).total_seconds(),
                                                                2))

                previousEvent = event

                userCumAttempts[userParc] += 1
                n_attempts[user_puzzle_key] += 1
                actualAtt += 1
                cumAttempts[user_puzzle_key] = actualAtt
                attemptsAux[userParc][task_id] = n_attempts[user_puzzle_key]


    # Guardar el instante final
    fin = time.time()

    # Calcular la diferencia en segundos
    diferencia = fin - inicio

    print("El proceso 1 tardó", diferencia, "segundos.")

    count = 0

    for i in puzzleEvents.keys():

        if(idComplete[i]==0):
            continue

        key_split = i.split('~')

        if(user_objective != 'all'):
            if not (key_split[1] in user_objective):
                continue
        if(group_objective != 'all'):
            if not (key_split[0] in group_objective):
                continue

        tic = time.time()
        # recortamos los eventos hasta el timestamp inicial del intento
        data_events_aux = timeLimits.computeTimeLimitEvents(dataEvents,user_objective=[key_split[1]], timeLimit= timestamp[i])

        # recuperamos el historial del usuario
        user_historial = uh.computeUserHistorial(data_events_aux,key_split[1])

        # recuperamos elo del jugador y dificultad ELO del puzzle
        totalData = elo.adaptedData(data_events_aux)
        if "user" in totalData.columns:
            user_elo = elo.run(1.8, 0.05, totalData, user_objective =key_split[1])
        else:
            user_elo = 0
        puzzle_elo = dict_elo_puzzles[key_split[2]]

        if(key_split[2] != '' and key_split[1] != '' and i != ''):

            # User, group and puzzle
            activity_by_user.at[i, 'group'] = key_split[0] # Grupo
            activity_by_user.at[i, 'user'] = key_split[1] # Usuario
            activity_by_user.at[i, 'task_id'] = key_split[2] # Puzzle
            activity_by_user.at[i, 'cum_this_puzzle_attempt'] = key_split[3] # Numero de intento de este usuario en este puzzle
            activity_by_user.at[i, 'timestamp'] = timestamp[i] # Timestamp inicial del intento

            # User historial. Percentage of tutorial,intermediate and advanced per puzzle. Attempts per puzzle
            activity_by_user.at[i, 'percentage_tutorial'] = user_historial['percentage_tutorial']
            activity_by_user.at[i, 'percentage_intermediate'] = user_historial['percentage_intermediate']
            activity_by_user.at[i, 'percentage_advanced'] = user_historial['percentage_advanced']
            activity_by_user.at[i, 'attempts_per_puzzle'] = user_historial['attempts_per_puzzle']

            # User and puzzle ELO
            activity_by_user.at[i, 'user_elo'] = user_elo
            activity_by_user.at[i, 'puzzle_elo'] = puzzle_elo

            # Puzzle difficulty
            activity_by_user.at[i, 'puzzle_difficulty'] = round(difficultyPuzzles[key_split[2]],2)

            # features of the attempt
            activity_by_user.at[i, 'n_events'] = puzzleEvents[i] #numero de eventos
            activity_by_user.at[i, 'n_check_solution'] = globalTypesEvents[i]['ws-check_solution'] #numero de submits
            activity_by_user.at[i, 'bestSubmit'] = bestSubmit[i] #numero de submits
            activity_by_user.at[i, 'n_breaks'] = breaksPuzzle[i] #numero de breaks en el intento
            activity_by_user.at[i, 'n_manipulation_events'] = manipulationEvents[i] #numero de intentos de manipulacion
            activity_by_user.at[i, 'n_snapshot'] = globalTypesEvents[i]['ws-snapshot']  #numero de snaphshots
            activity_by_user.at[i, 'n_rotate_view'] = globalTypesEvents[i]['ws-rotate_view'] #numero de rotaciones
            activity_by_user.at[i, 'time_failed_submission_exit'] = timeSubExit[i] #tiempo entre submit y exit
            activity_by_user.at[i, 'avg_time_between_submissions'] = timeBetweenSub[i] #tiempo entre submits

            # label of the attempt
            activity_by_user.at[i, 'completed'] = completados[i] #Ha completado el puzzle o no

        tac = time.time()
        print('El intento ' + str(count) + ' tardó ' + str(tac-tic) + ' segundos.')
        count += 1

    #delete row with NaN
    activity_by_user.dropna(subset = ['user'], inplace=True)

    #data output preparation
    activity_by_user = pd.DataFrame(activity_by_user, columns=['group', 'user','task_id','cum_this_puzzle_attempt','timestamp','percentage_tutorial','percentage_intermediate','percentage_advanced','attempts_per_puzzle','user_elo','puzzle_elo','puzzle_difficulty','n_events','n_check_solution','bestSubmit','n_breaks','n_manipulation_events','n_snapshot','n_rotate_view','completed'])

    # Crear una instancia del codificador
    encoder = OneHotEncoder()

    # Ajustar el codificador a los datos
    encoder.fit(activity_by_user[['task_id']])

    # Transformar los datos
    encoded_data = encoder.transform(activity_by_user[['task_id']]).toarray()

    # Crear un nuevo DataFrame con los datos codificados
    encoded_df = pd.DataFrame(encoded_data, columns=encoder.categories_[0])

    # Agregar las nuevas columnas al DataFrame original
    activity_by_user = activity_by_user.reset_index(drop=True)
    encoded_df = encoded_df.reset_index(drop=True)
    activity_by_user_encoded = pd.concat([activity_by_user, encoded_df], axis=1)

    return activity_by_user_encoded

# %%
features = computeFeatures(dataEvents,percentil=1)
# Out:
# El proceso 1 tardó 105.56567144393921 segundos.
# El intento 0 tardó 0.08146476745605469 segundos.
# El intento 1 tardó 0.07951211929321289 segundos.
# El intento 2 tardó 0.08851289749145508 segundos.
# El intento 3 tardó 0.09652042388916016 segundos.
# El intento 4 tardó 0.10465836524963379 segundos.
# El intento 5 tardó 0.11162972450256348 segundos.
# El intento 6 tardó 0.11146736145019531 segundos.
# El intento 7 tardó 0.11951017379760742 segundos.
# El intento 8 tardó 0.11914563179016113 segundos.
# El intento 9 tardó 0.12524008750915527 segundos.
# El intento 10 tardó 0.13069820404052734 segundos.
# El intento 11 tardó 0.16464614868164062 segundos.
# El intento 12 tardó 0.17311334609985352 segundos.
# El intento 13 tardó 0.17434096336364746 segundos.
# El intento 14 tardó 0.1968839168548584 segundos.
# El intento 15 tardó 0.2152566909790039 segundos.
# El intento 16 tardó 0.2625410556793213 segundos.
# El intento 17 tardó 0.26003026962280273 segundos.
# El intento 18 tardó 0.2825474739074707 segundos.
# El intento 19 tardó 0.2785375118255615 segundos.
# El intento 20 tardó 0.2905611991882324 segundos.
# El intento 21 tardó 0.2976572513580322 segundos.
# El intento 22 tardó 0.3128492832183838 segundos.
# El intento 23 tardó 0.3334026336669922 segundos.
# El intento 24 tardó 0.3426811695098877 segundos.
# El intento 25 tardó 0.3495957851409912 segundos.
# El intento 26 tardó 0.3549318313598633 segundos.
# El intento 27 tardó 0.3508467674255371 segundos.
# El intento 28 tardó 0.3492734432220459 segundos.
# El intento 29 tardó 0.38303613662719727 segundos.
# El intento 30 tardó 0.08200621604919434 segundos.
# El intento 31 tardó 0.09152603149414062 segundos.
# El intento 32 tardó 0.08655095100402832 segundos.
# El intento 33 tardó 0.09261918067932129 segundos.
# El intento 34 tardó 0.09568524360656738 segundos.
# El intento 35 tardó 0.11961483955383301 segundos.
# El intento 36 tardó 0.12966656684875488 segundos.
# El intento 37 tardó 0.154188871383667 segundos.
# El intento 38 tardó 0.15121793746948242 segundos.
# El intento 39 tardó 0.16054153442382812 segundos.
# El intento 40 tardó 0.18828225135803223 segundos.
# El intento 41 tardó 0.1753215789794922 segundos.
# El intento 42 tardó 0.20733308792114258 segundos.
# El intento 43 tardó 0.22667288780212402 segundos.
# El intento 44 tardó 0.24982452392578125 segundos.
# El intento 45 tardó 0.24213790893554688 segundos.
# El intento 46 tardó 0.24143505096435547 segundos.
# El intento 47 tardó 0.23679375648498535 segundos.
# El intento 48 tardó 0.24711394309997559 segundos.
# El intento 49 tardó 0.2449359893798828 segundos.
# El intento 50 tardó 0.35492825508117676 segundos.
# El intento 51 tardó 0.8795790672302246 segundos.
# El intento 52 tardó 0.8508081436157227 segundos.
# El intento 53 tardó 0.08405137062072754 segundos.
# El intento 54 tardó 0.09359431266784668 segundos.
# El intento 55 tardó 0.10662508010864258 segundos.
# El intento 56 tardó 0.10954833030700684 segundos.
# El intento 57 tardó 0.1087799072265625 segundos.
# El intento 58 tardó 0.11064910888671875 segundos.
# El intento 59 tardó 0.10465192794799805 segundos.
# El intento 60 tardó 0.1266331672668457 segundos.
# El intento 61 tardó 0.1395721435546875 segundos.
# El intento 62 tardó 0.15603280067443848 segundos.
# El intento 63 tardó 0.17320966720581055 segundos.
# El intento 64 tardó 0.20130228996276855 segundos.
# El intento 65 tardó 0.22930598258972168 segundos.
# El intento 66 tardó 0.23431062698364258 segundos.
# El intento 67 tardó 0.229902982711792 segundos.
# El intento 68 tardó 0.24307823181152344 segundos.
# El intento 69 tardó 0.2855260372161865 segundos.
# El intento 70 tardó 0.2705390453338623 segundos.
# El intento 71 tardó 0.26219820976257324 segundos.
# El intento 72 tardó 0.2826507091522217 segundos.
# El intento 73 tardó 0.2935209274291992 segundos.
# El intento 74 tardó 0.312549352645874 segundos.
# El intento 75 tardó 0.3265988826751709 segundos.
# El intento 76 tardó 0.33524394035339355 segundos.
# El intento 77 tardó 0.3355436325073242 segundos.
# El intento 78 tardó 0.07350850105285645 segundos.
# El intento 79 tardó 0.08369565010070801 segundos.
# El intento 80 tardó 0.08605527877807617 segundos.
# El intento 81 tardó 0.0905606746673584 segundos.
# El intento 82 tardó 0.09851264953613281 segundos.
# El intento 83 tardó 0.12701916694641113 segundos.
# El intento 84 tardó 0.13667654991149902 segundos.
# El intento 85 tardó 0.1386408805847168 segundos.
# El intento 86 tardó 0.14989805221557617 segundos.
# El intento 87 tardó 0.16524791717529297 segundos.
# El intento 88 tardó 0.1746537685394287 segundos.
# El intento 89 tardó 0.1683061122894287 segundos.
# El intento 90 tardó 0.18017148971557617 segundos.
# El intento 91 tardó 0.2064981460571289 segundos.
# El intento 92 tardó 0.21303200721740723 segundos.
# El intento 93 tardó 0.2180328369140625 segundos.
# El intento 94 tardó 0.2170250415802002 segundos.
# El intento 95 tardó 0.30762267112731934 segundos.
# El intento 96 tardó 0.3258171081542969 segundos.
# El intento 97 tardó 0.3535590171813965 segundos.
# El intento 98 tardó 0.9410696029663086 segundos.
# El intento 99 tardó 0.08800244331359863 segundos.
# El intento 100 tardó 0.10153007507324219 segundos.
# El intento 101 tardó 0.10051798820495605 segundos.
# El intento 102 tardó 0.11003518104553223 segundos.
# El intento 103 tardó 0.13056492805480957 segundos.
# El intento 104 tardó 0.1415245532989502 segundos.
# El intento 105 tardó 0.14601945877075195 segundos.
# El intento 106 tardó 0.1625196933746338 segundos.
# El intento 107 tardó 0.2167518138885498 segundos.
# El intento 108 tardó 0.21517539024353027 segundos.
# El intento 109 tardó 0.20904040336608887 segundos.
# El intento 110 tardó 0.2370750904083252 segundos.
# El intento 111 tardó 0.07851338386535645 segundos.
# El intento 112 tardó 0.09011316299438477 segundos.
# El intento 113 tardó 0.09254646301269531 segundos.
# El intento 114 tardó 0.09651541709899902 segundos.
# El intento 115 tardó 0.1045222282409668 segundos.
# El intento 116 tardó 0.10152077674865723 segundos.
# El intento 117 tardó 0.10752272605895996 segundos.
# El intento 118 tardó 0.10863709449768066 segundos.
# El intento 119 tardó 0.12851166725158691 segundos.
# El intento 120 tardó 0.14102673530578613 segundos.
# El intento 121 tardó 0.14951467514038086 segundos.
# El intento 122 tardó 0.16658306121826172 segundos.
# El intento 123 tardó 0.1792445182800293 segundos.
# El intento 124 tardó 0.19913029670715332 segundos.
# El intento 125 tardó 0.0820918083190918 segundos.
# El intento 126 tardó 0.08955979347229004 segundos.
# El intento 127 tardó 0.0966191291809082 segundos.
# El intento 128 tardó 0.09757065773010254 segundos.
# El intento 129 tardó 0.09729409217834473 segundos.
# El intento 130 tardó 0.1005551815032959 segundos.
# El intento 131 tardó 0.1246337890625 segundos.
# El intento 132 tardó 0.12302184104919434 segundos.
# El intento 133 tardó 0.1315135955810547 segundos.
# El intento 134 tardó 0.14166259765625 segundos.
# El intento 135 tardó 0.1533064842224121 segundos.
# El intento 136 tardó 0.21597838401794434 segundos.
# El intento 137 tardó 0.18086695671081543 segundos.
# El intento 138 tardó 0.20219826698303223 segundos.
# El intento 139 tardó 0.26203155517578125 segundos.
# El intento 140 tardó 0.2670714855194092 segundos.
# El intento 141 tardó 0.28262925148010254 segundos.
# El intento 142 tardó 0.29686856269836426 segundos.
# El intento 143 tardó 0.41731953620910645 segundos.
# El intento 144 tardó 0.2899148464202881 segundos.
# El intento 145 tardó 0.3095824718475342 segundos.
# El intento 146 tardó 0.3332042694091797 segundos.
# El intento 147 tardó 0.09643769264221191 segundos.
# El intento 148 tardó 0.10547447204589844 segundos.
# El intento 149 tardó 0.10555863380432129 segundos.
# El intento 150 tardó 0.109344482421875 segundos.
# El intento 151 tardó 0.11054420471191406 segundos.
# El intento 152 tardó 0.13456940650939941 segundos.
# El intento 153 tardó 0.19165754318237305 segundos.
# El intento 154 tardó 0.17506909370422363 segundos.
# El intento 155 tardó 0.1926732063293457 segundos.
# El intento 156 tardó 0.20206880569458008 segundos.
# El intento 157 tardó 0.23009347915649414 segundos.
# El intento 158 tardó 0.24469757080078125 segundos.
# El intento 159 tardó 0.22292804718017578 segundos.
# El intento 160 tardó 0.24017047882080078 segundos.
# El intento 161 tardó 0.20910072326660156 segundos.
# El intento 162 tardó 0.22040271759033203 segundos.
# El intento 163 tardó 0.08551621437072754 segundos.
# El intento 164 tardó 0.09453082084655762 segundos.
# El intento 165 tardó 0.10151529312133789 segundos.
# El intento 166 tardó 0.11855101585388184 segundos.
# El intento 167 tardó 0.15005278587341309 segundos.
# El intento 168 tardó 0.1434619426727295 segundos.
# El intento 169 tardó 0.14769315719604492 segundos.
# El intento 170 tardó 0.15474271774291992 segundos.
# El intento 171 tardó 0.19018101692199707 segundos.
# El intento 172 tardó 0.07557511329650879 segundos.
# El intento 173 tardó 0.08700823783874512 segundos.
# El intento 174 tardó 0.0845494270324707 segundos.
# El intento 175 tardó 0.11465048789978027 segundos.
# El intento 176 tardó 0.11665010452270508 segundos.
# El intento 177 tardó 0.1246500015258789 segundos.
# El intento 178 tardó 0.12713384628295898 segundos.
# El intento 179 tardó 0.1406097412109375 segundos.
# El intento 180 tardó 0.08158469200134277 segundos.
# El intento 181 tardó 0.08351635932922363 segundos.
# El intento 182 tardó 0.08751487731933594 segundos.
# El intento 183 tardó 0.09650921821594238 segundos.
# El intento 184 tardó 0.10061407089233398 segundos.
# El intento 185 tardó 0.12369203567504883 segundos.
# El intento 186 tardó 0.12862133979797363 segundos.
# El intento 187 tardó 0.13270187377929688 segundos.
# El intento 188 tardó 0.15975213050842285 segundos.
# El intento 189 tardó 0.15233564376831055 segundos.
# El intento 190 tardó 0.1731104850769043 segundos.
# El intento 191 tardó 0.17926263809204102 segundos.
# El intento 192 tardó 0.1897897720336914 segundos.
# El intento 193 tardó 0.1912531852722168 segundos.
# El intento 194 tardó 0.22181940078735352 segundos.
# El intento 195 tardó 0.27735066413879395 segundos.
# El intento 196 tardó 0.26494932174682617 segundos.
# El intento 197 tardó 0.2554185390472412 segundos.
# El intento 198 tardó 0.3761894702911377 segundos.
# El intento 199 tardó 0.08761119842529297 segundos.
# El intento 200 tardó 0.09664011001586914 segundos.
# El intento 201 tardó 0.10055112838745117 segundos.
# El intento 202 tardó 0.12266302108764648 segundos.
# El intento 203 tardó 0.15058016777038574 segundos.
# El intento 204 tardó 0.2010488510131836 segundos.
# El intento 205 tardó 0.1813664436340332 segundos.
# El intento 206 tardó 0.1943190097808838 segundos.
# El intento 207 tardó 0.19108986854553223 segundos.
# El intento 208 tardó 0.08116841316223145 segundos.
# El intento 209 tardó 0.12147068977355957 segundos.
# El intento 210 tardó 0.13757109642028809 segundos.
# El intento 211 tardó 0.13793134689331055 segundos.
# El intento 212 tardó 0.14062237739562988 segundos.
# El intento 213 tardó 0.1458425521850586 segundos.
# El intento 214 tardó 0.1585996150970459 segundos.
# El intento 215 tardó 0.172257661819458 segundos.
# El intento 216 tardó 0.18825387954711914 segundos.
# El intento 217 tardó 0.20305585861206055 segundos.
# El intento 218 tardó 0.2092883586883545 segundos.
# El intento 219 tardó 0.20930266380310059 segundos.
# El intento 220 tardó 0.21429443359375 segundos.
# El intento 221 tardó 0.21620845794677734 segundos.
# El intento 222 tardó 0.22281360626220703 segundos.
# El intento 223 tardó 0.07600617408752441 segundos.
# El intento 224 tardó 0.08658528327941895 segundos.
# El intento 225 tardó 0.09162068367004395 segundos.
# El intento 226 tardó 0.09068107604980469 segundos.
# El intento 227 tardó 0.10267901420593262 segundos.
# El intento 228 tardó 0.10359549522399902 segundos.
# El intento 229 tardó 0.11738705635070801 segundos.
# El intento 230 tardó 0.12651753425598145 segundos.
# El intento 231 tardó 0.13211727142333984 segundos.
# El intento 232 tardó 0.1217038631439209 segundos.
# El intento 233 tardó 0.15078020095825195 segundos.
# El intento 234 tardó 0.15841960906982422 segundos.
# El intento 235 tardó 0.15969061851501465 segundos.
# El intento 236 tardó 0.18104982376098633 segundos.
# El intento 237 tardó 0.18850445747375488 segundos.
# El intento 238 tardó 0.21150994300842285 segundos.
# El intento 239 tardó 0.23628568649291992 segundos.
# El intento 240 tardó 0.2372136116027832 segundos.
# El intento 241 tardó 0.2517433166503906 segundos.
# El intento 242 tardó 0.2641716003417969 segundos.
# El intento 243 tardó 0.26262998580932617 segundos.
# El intento 244 tardó 0.26731085777282715 segundos.
# El intento 245 tardó 0.293959379196167 segundos.
# El intento 246 tardó 0.3276515007019043 segundos.
# El intento 247 tardó 0.32018589973449707 segundos.
# El intento 248 tardó 0.3316824436187744 segundos.
# El intento 249 tardó 0.3612360954284668 segundos.
# El intento 250 tardó 0.3802189826965332 segundos.
# El intento 251 tardó 0.39421749114990234 segundos.
# El intento 252 tardó 0.4232521057128906 segundos.
# El intento 253 tardó 0.48478078842163086 segundos.
# El intento 254 tardó 0.07556033134460449 segundos.
# El intento 255 tardó 0.08601951599121094 segundos.
# El intento 256 tardó 0.09252405166625977 segundos.
# El intento 257 tardó 0.09457230567932129 segundos.
# El intento 258 tardó 0.11557340621948242 segundos.
# El intento 259 tardó 0.12818479537963867 segundos.
# El intento 260 tardó 0.13455915451049805 segundos.
# El intento 261 tardó 0.14110636711120605 segundos.
# El intento 262 tardó 0.14156055450439453 segundos.
# El intento 263 tardó 0.17917180061340332 segundos.
# El intento 264 tardó 0.1892869472503662 segundos.
# El intento 265 tardó 0.20330095291137695 segundos.
# El intento 266 tardó 0.24007129669189453 segundos.
# El intento 267 tardó 0.08356428146362305 segundos.
# El intento 268 tardó 0.09097027778625488 segundos.
# El intento 269 tardó 0.11365151405334473 segundos.
# El intento 270 tardó 0.12965917587280273 segundos.
# El intento 271 tardó 0.12824201583862305 segundos.
# El intento 272 tardó 0.13261032104492188 segundos.
# El intento 273 tardó 0.13565945625305176 segundos.
# El intento 274 tardó 0.13729095458984375 segundos.
# El intento 275 tardó 0.14659452438354492 segundos.
# El intento 276 tardó 0.08283209800720215 segundos.
# El intento 277 tardó 0.08250713348388672 segundos.
# El intento 278 tardó 0.08451342582702637 segundos.
# El intento 279 tardó 0.0827791690826416 segundos.
# El intento 280 tardó 0.09260153770446777 segundos.
# El intento 281 tardó 0.1096951961517334 segundos.
# El intento 282 tardó 0.11355042457580566 segundos.
# El intento 283 tardó 0.133697509765625 segundos.
# El intento 284 tardó 0.13446474075317383 segundos.
# El intento 285 tardó 0.0835103988647461 segundos.
# El intento 286 tardó 0.09050893783569336 segundos.
# El intento 287 tardó 0.09251117706298828 segundos.
# El intento 288 tardó 0.09521698951721191 segundos.
# El intento 289 tardó 0.10151243209838867 segundos.
# El intento 290 tardó 0.10350894927978516 segundos.
# El intento 291 tardó 0.10450935363769531 segundos.
# El intento 292 tardó 0.11651301383972168 segundos.
# El intento 293 tardó 0.10950922966003418 segundos.
# El intento 294 tardó 0.11851191520690918 segundos.
# El intento 295 tardó 0.12707209587097168 segundos.
# El intento 296 tardó 0.12165331840515137 segundos.
# El intento 297 tardó 0.12146830558776855 segundos.
# El intento 298 tardó 0.13460731506347656 segundos.
# El intento 299 tardó 0.1402451992034912 segundos.
# El intento 300 tardó 0.15047907829284668 segundos.
# El intento 301 tardó 0.1687169075012207 segundos.
# El intento 302 tardó 0.17103075981140137 segundos.
# El intento 303 tardó 0.17651963233947754 segundos.
# El intento 304 tardó 0.18502593040466309 segundos.
# El intento 305 tardó 0.07825708389282227 segundos.
# El intento 306 tardó 0.08451652526855469 segundos.
# El intento 307 tardó 0.1205148696899414 segundos.
# El intento 308 tardó 0.13405227661132812 segundos.
# El intento 309 tardó 0.16103506088256836 segundos.
# El intento 310 tardó 0.16568756103515625 segundos.
# El intento 311 tardó 0.19102787971496582 segundos.
# El intento 312 tardó 0.2205507755279541 segundos.
# El intento 313 tardó 0.2320261001586914 segundos.
# El intento 314 tardó 0.2725503444671631 segundos.
# El intento 315 tardó 0.28435850143432617 segundos.
# El intento 316 tardó 0.07651424407958984 segundos.
# El intento 317 tardó 0.08800721168518066 segundos.
# El intento 318 tardó 0.10551762580871582 segundos.
# El intento 319 tardó 0.0995171070098877 segundos.
# El intento 320 tardó 0.10601997375488281 segundos.
# El intento 321 tardó 0.12453389167785645 segundos.
# El intento 322 tardó 0.11955833435058594 segundos.
# El intento 323 tardó 0.12122225761413574 segundos.
# El intento 324 tardó 0.13250327110290527 segundos.
# El intento 325 tardó 0.1500227451324463 segundos.
# El intento 326 tardó 0.20002269744873047 segundos.
# El intento 327 tardó 0.22502851486206055 segundos.
# El intento 328 tardó 0.2245626449584961 segundos.
# El intento 329 tardó 0.22171497344970703 segundos.
# El intento 330 tardó 0.21330666542053223 segundos.
# El intento 331 tardó 0.22616171836853027 segundos.
# El intento 332 tardó 0.27382802963256836 segundos.
# El intento 333 tardó 0.24198031425476074 segundos.
# El intento 334 tardó 0.2525370121002197 segundos.
# El intento 335 tardó 0.32469773292541504 segundos.
# El intento 336 tardó 0.10251975059509277 segundos.
# El intento 337 tardó 0.17203164100646973 segundos.
# El intento 338 tardó 0.1664257049560547 segundos.
# El intento 339 tardó 0.07956552505493164 segundos.
# El intento 340 tardó 0.08968615531921387 segundos.
# El intento 341 tardó 0.08959650993347168 segundos.
# El intento 342 tardó 0.09664392471313477 segundos.
# El intento 343 tardó 0.11261510848999023 segundos.
# El intento 344 tardó 0.11765241622924805 segundos.
# El intento 345 tardó 0.13230252265930176 segundos.
# El intento 346 tardó 0.13268399238586426 segundos.
# El intento 347 tardó 0.12888479232788086 segundos.
# El intento 348 tardó 0.14963436126708984 segundos.
# El intento 349 tardó 0.1616215705871582 segundos.
# El intento 350 tardó 0.1781630516052246 segundos.
# El intento 351 tardó 0.19208836555480957 segundos.
# El intento 352 tardó 0.21197104454040527 segundos.
# El intento 353 tardó 0.2403566837310791 segundos.
# El intento 354 tardó 0.24020004272460938 segundos.
# El intento 355 tardó 0.264387845993042 segundos.
# El intento 356 tardó 0.2882373332977295 segundos.
# El intento 357 tardó 0.28980493545532227 segundos.
# El intento 358 tardó 0.2978212833404541 segundos.
# El intento 359 tardó 0.3273732662200928 segundos.
# El intento 360 tardó 0.3306906223297119 segundos.
# El intento 361 tardó 0.3574223518371582 segundos.
# El intento 362 tardó 0.08799505233764648 segundos.
# El intento 363 tardó 0.0906069278717041 segundos.
# El intento 364 tardó 0.0975644588470459 segundos.
# El intento 365 tardó 0.10160040855407715 segundos.
# El intento 366 tardó 0.13927245140075684 segundos.
# El intento 367 tardó 0.14539051055908203 segundos.
# El intento 368 tardó 0.18535089492797852 segundos.
# El intento 369 tardó 0.19128632545471191 segundos.
# El intento 370 tardó 0.20112347602844238 segundos.
# El intento 371 tardó 0.2302255630493164 segundos.
# El intento 372 tardó 0.273937463760376 segundos.
# El intento 373 tardó 0.07848691940307617 segundos.
# El intento 374 tardó 0.1086738109588623 segundos.
# El intento 375 tardó 0.1216127872467041 segundos.
# El intento 376 tardó 0.12966346740722656 segundos.
# El intento 377 tardó 0.13728070259094238 segundos.
# El intento 378 tardó 0.1286468505859375 segundos.
# El intento 379 tardó 0.14267945289611816 segundos.
# El intento 380 tardó 0.16924452781677246 segundos.
# El intento 381 tardó 0.17026996612548828 segundos.
# El intento 382 tardó 0.1702413558959961 segundos.
# El intento 383 tardó 0.08609557151794434 segundos.
# El intento 384 tardó 0.09548497200012207 segundos.
# El intento 385 tardó 0.09564352035522461 segundos.
# El intento 386 tardó 0.09765005111694336 segundos.
# El intento 387 tardó 0.07865285873413086 segundos.
# El intento 388 tardó 0.07764768600463867 segundos.
# El intento 389 tardó 0.0826108455657959 segundos.
# El intento 390 tardó 0.0935373306274414 segundos.
# El intento 391 tardó 0.08905529975891113 segundos.
# El intento 392 tardó 0.12026262283325195 segundos.
# El intento 393 tardó 0.12789607048034668 segundos.
# El intento 394 tardó 0.12820076942443848 segundos.
# El intento 395 tardó 0.15223026275634766 segundos.
# El intento 396 tardó 0.14864540100097656 segundos.
# El intento 397 tardó 0.1671764850616455 segundos.
# El intento 398 tardó 0.17166924476623535 segundos.
# El intento 399 tardó 0.19426298141479492 segundos.
# El intento 400 tardó 0.2658238410949707 segundos.
# El intento 401 tardó 0.24590635299682617 segundos.
# El intento 402 tardó 0.27625560760498047 segundos.
# El intento 403 tardó 0.29807591438293457 segundos.
# El intento 404 tardó 0.29778289794921875 segundos.
# El intento 405 tardó 0.34624314308166504 segundos.
# El intento 406 tardó 0.3628346920013428 segundos.
# El intento 407 tardó 0.3787648677825928 segundos.
# El intento 408 tardó 0.36957263946533203 segundos.
# El intento 409 tardó 0.08269572257995605 segundos.
# El intento 410 tardó 0.08423829078674316 segundos.
# El intento 411 tardó 0.09224367141723633 segundos.
# El intento 412 tardó 0.09104251861572266 segundos.
# El intento 413 tardó 0.10531020164489746 segundos.
# El intento 414 tardó 0.11065077781677246 segundos.
# El intento 415 tardó 0.11357283592224121 segundos.
# El intento 416 tardó 0.11854219436645508 segundos.
# El intento 417 tardó 0.14164113998413086 segundos.
# El intento 418 tardó 0.14216184616088867 segundos.
# El intento 419 tardó 0.15461206436157227 segundos.
# El intento 420 tardó 0.16329717636108398 segundos.
# El intento 421 tardó 0.17627191543579102 segundos.
# El intento 422 tardó 0.08465194702148438 segundos.
# El intento 423 tardó 0.09304523468017578 segundos.
# El intento 424 tardó 0.1121511459350586 segundos.
# El intento 425 tardó 0.11567568778991699 segundos.
# El intento 426 tardó 0.11364507675170898 segundos.
# El intento 427 tardó 0.14871501922607422 segundos.
# El intento 428 tardó 0.1652512550354004 segundos.
# El intento 429 tardó 0.16628336906433105 segundos.
# El intento 430 tardó 0.1932990550994873 segundos.
# El intento 431 tardó 0.20729851722717285 segundos.
# El intento 432 tardó 0.21230411529541016 segundos.
# El intento 433 tardó 0.08565235137939453 segundos.
# El intento 434 tardó 0.09165334701538086 segundos.
# El intento 435 tardó 0.1016397476196289 segundos.
# El intento 436 tardó 0.1036520004272461 segundos.
# El intento 437 tardó 0.11855173110961914 segundos.
# El intento 438 tardó 0.11255431175231934 segundos.
# El intento 439 tardó 0.12668514251708984 segundos.
# El intento 440 tardó 0.08750748634338379 segundos.
# El intento 441 tardó 0.0875093936920166 segundos.
# El intento 442 tardó 0.1005098819732666 segundos.
# El intento 443 tardó 0.11855435371398926 segundos.
# El intento 444 tardó 0.12883782386779785 segundos.
# El intento 445 tardó 0.12208342552185059 segundos.
# El intento 446 tardó 0.12864971160888672 segundos.
# El intento 447 tardó 0.1372671127319336 segundos.
# El intento 448 tardó 0.15428924560546875 segundos.
# El intento 449 tardó 0.15665078163146973 segundos.
# El intento 450 tardó 0.16052794456481934 segundos.
# El intento 451 tardó 0.17253446578979492 segundos.
# El intento 452 tardó 0.1617114543914795 segundos.
# El intento 453 tardó 0.18809270858764648 segundos.
# El intento 454 tardó 0.17105555534362793 segundos.
# El intento 455 tardó 0.21074700355529785 segundos.
# El intento 456 tardó 0.21497678756713867 segundos.
# El intento 457 tardó 0.22604823112487793 segundos.
# El intento 458 tardó 0.25539660453796387 segundos.
# El intento 459 tardó 0.24203801155090332 segundos.
# El intento 460 tardó 0.2525362968444824 segundos.
# El intento 461 tardó 0.3040306568145752 segundos.
# El intento 462 tardó 0.30554890632629395 segundos.
# El intento 463 tardó 0.10054278373718262 segundos.
# El intento 464 tardó 0.10554981231689453 segundos.
# El intento 465 tardó 0.12352561950683594 segundos.
# El intento 466 tardó 0.11704349517822266 segundos.
# El intento 467 tardó 0.18252062797546387 segundos.
# El intento 468 tardó 0.18802595138549805 segundos.
# El intento 469 tardó 0.21053457260131836 segundos.
# El intento 470 tardó 0.22422218322753906 segundos.
# El intento 471 tardó 0.10357284545898438 segundos.
# El intento 472 tardó 0.11260676383972168 segundos.
# El intento 473 tardó 0.11168026924133301 segundos.
# El intento 474 tardó 0.12861371040344238 segundos.
# El intento 475 tardó 0.12066864967346191 segundos.
# El intento 476 tardó 0.13322830200195312 segundos.
# El intento 477 tardó 0.1355745792388916 segundos.
# El intento 478 tardó 0.15511870384216309 segundos.
# El intento 479 tardó 0.15452885627746582 segundos.
# El intento 480 tardó 0.16706609725952148 segundos.
# El intento 481 tardó 0.18319177627563477 segundos.
# El intento 482 tardó 0.17769265174865723 segundos.
# El intento 483 tardó 0.19822239875793457 segundos.
# El intento 484 tardó 0.20529818534851074 segundos.
# El intento 485 tardó 0.22162985801696777 segundos.
# El intento 486 tardó 0.2445981502532959 segundos.
# El intento 487 tardó 0.25821948051452637 segundos.
# El intento 488 tardó 0.24294209480285645 segundos.
# El intento 489 tardó 0.2544076442718506 segundos.
# El intento 490 tardó 0.2663147449493408 segundos.
# El intento 491 tardó 0.27692294120788574 segundos.
# El intento 492 tardó 0.28136634826660156 segundos.
# El intento 493 tardó 0.2947249412536621 segundos.
# El intento 494 tardó 0.31037044525146484 segundos.
# El intento 495 tardó 0.3224503993988037 segundos.
# El intento 496 tardó 0.3542914390563965 segundos.
# El intento 497 tardó 0.399486780166626 segundos.
# El intento 498 tardó 0.400134801864624 segundos.
# El intento 499 tardó 0.5294773578643799 segundos.
# El intento 500 tardó 0.10364484786987305 segundos.
# El intento 501 tardó 0.10640621185302734 segundos.
# El intento 502 tardó 0.1015007495880127 segundos.
# El intento 503 tardó 0.11025691032409668 segundos.
# El intento 504 tardó 0.11942076683044434 segundos.
# El intento 505 tardó 0.14780616760253906 segundos.
# El intento 506 tardó 0.14262700080871582 segundos.
# El intento 507 tardó 0.15414977073669434 segundos.
# El intento 508 tardó 0.1665782928466797 segundos.
# El intento 509 tardó 0.16611456871032715 segundos.
# El intento 510 tardó 0.16877150535583496 segundos.
# El intento 511 tardó 0.17912006378173828 segundos.
# El intento 512 tardó 0.19996166229248047 segundos.
# El intento 513 tardó 0.22010231018066406 segundos.
# El intento 514 tardó 0.09068679809570312 segundos.
# El intento 515 tardó 0.09360742568969727 segundos.
# El intento 516 tardó 0.10359692573547363 segundos.
# El intento 517 tardó 0.10669636726379395 segundos.
# El intento 518 tardó 0.10865187644958496 segundos.
# El intento 519 tardó 0.1185765266418457 segundos.
# El intento 520 tardó 0.11567115783691406 segundos.
# El intento 521 tardó 0.13529157638549805 segundos.
# El intento 522 tardó 0.13752532005310059 segundos.
# El intento 523 tardó 0.15073704719543457 segundos.
# El intento 524 tardó 0.17721223831176758 segundos.
# El intento 525 tardó 0.17878055572509766 segundos.
# El intento 526 tardó 0.19427132606506348 segundos.
# El intento 527 tardó 0.20725083351135254 segundos.
# El intento 528 tardó 0.22223854064941406 segundos.
# El intento 529 tardó 0.22934985160827637 segundos.
# El intento 530 tardó 0.26570987701416016 segundos.
# El intento 531 tardó 0.2629427909851074 segundos.
# El intento 532 tardó 0.2732515335083008 segundos.
# El intento 533 tardó 0.26784515380859375 segundos.
# El intento 534 tardó 0.0876626968383789 segundos.
# El intento 535 tardó 0.09160423278808594 segundos.
# El intento 536 tardó 0.09564781188964844 segundos.
# El intento 537 tardó 0.11462521553039551 segundos.
# El intento 538 tardó 0.11152815818786621 segundos.
# El intento 539 tardó 0.1295146942138672 segundos.
# El intento 540 tardó 0.08455204963684082 segundos.
# El intento 541 tardó 0.08864521980285645 segundos.
# El intento 542 tardó 0.09760427474975586 segundos.
# El intento 543 tardó 0.07955479621887207 segundos.
# El intento 544 tardó 0.09259438514709473 segundos.
# El intento 545 tardó 0.09363913536071777 segundos.
# El intento 546 tardó 0.10147404670715332 segundos.
# El intento 547 tardó 0.10750961303710938 segundos.
# El intento 548 tardó 0.11065173149108887 segundos.
# El intento 549 tardó 0.11646652221679688 segundos.
# El intento 550 tardó 0.15641236305236816 segundos.
# El intento 551 tardó 0.1536552906036377 segundos.
# El intento 552 tardó 0.16571307182312012 segundos.
# El intento 553 tardó 0.18103814125061035 segundos.
# El intento 554 tardó 0.20903730392456055 segundos.
# El intento 555 tardó 0.2150287628173828 segundos.
# El intento 556 tardó 0.21003460884094238 segundos.
# El intento 557 tardó 0.21802592277526855 segundos.
# El intento 558 tardó 0.24621868133544922 segundos.
# El intento 559 tardó 0.24724149703979492 segundos.
# El intento 560 tardó 0.24842476844787598 segundos.
# El intento 561 tardó 0.24662089347839355 segundos.
# El intento 562 tardó 0.2725651264190674 segundos.
# El intento 563 tardó 0.2855570316314697 segundos.
# El intento 564 tardó 0.25702667236328125 segundos.
# El intento 565 tardó 0.26746416091918945 segundos.
# El intento 566 tardó 0.28520631790161133 segundos.
# El intento 567 tardó 0.2805349826812744 segundos.
# El intento 568 tardó 0.2719297409057617 segundos.
# El intento 569 tardó 0.28324389457702637 segundos.
# El intento 570 tardó 0.3059561252593994 segundos.
# El intento 571 tardó 0.28358030319213867 segundos.
# El intento 572 tardó 0.29450154304504395 segundos.
# El intento 573 tardó 0.29071712493896484 segundos.
# El intento 574 tardó 0.30565476417541504 segundos.
# El intento 575 tardó 0.3085668087005615 segundos.
# El intento 576 tardó 0.3452126979827881 segundos.
# El intento 577 tardó 0.09001493453979492 segundos.
# El intento 578 tardó 0.12808632850646973 segundos.
# El intento 579 tardó 0.12856698036193848 segundos.
# El intento 580 tardó 0.13557052612304688 segundos.
# El intento 581 tardó 0.14208531379699707 segundos.
# El intento 582 tardó 0.16324710845947266 segundos.
# El intento 583 tardó 0.1681973934173584 segundos.
# El intento 584 tardó 0.14719223976135254 segundos.
# El intento 585 tardó 0.16048717498779297 segundos.
# El intento 586 tardó 0.16411447525024414 segundos.
# El intento 587 tardó 0.1766979694366455 segundos.
# El intento 588 tardó 0.17962431907653809 segundos.
# El intento 589 tardó 0.19006896018981934 segundos.
# El intento 590 tardó 0.21312999725341797 segundos.
# El intento 591 tardó 0.21165943145751953 segundos.
# El intento 592 tardó 0.21370863914489746 segundos.
# El intento 593 tardó 0.22808241844177246 segundos.
# El intento 594 tardó 0.2720332145690918 segundos.
# El intento 595 tardó 0.3315577507019043 segundos.
# El intento 596 tardó 0.3076341152191162 segundos.
# El intento 597 tardó 0.35825061798095703 segundos.
# El intento 598 tardó 0.29462671279907227 segundos.
# El intento 599 tardó 0.47112560272216797 segundos.
# El intento 600 tardó 0.43892407417297363 segundos.
# El intento 601 tardó 0.34767627716064453 segundos.
# El intento 602 tardó 0.43775081634521484 segundos.
# El intento 603 tardó 0.43331217765808105 segundos.
# El intento 604 tardó 0.4033029079437256 segundos.
# El intento 605 tardó 0.39042067527770996 segundos.
# El intento 606 tardó 0.4231898784637451 segundos.
# El intento 607 tardó 0.4877650737762451 segundos.
# El intento 608 tardó 0.08962130546569824 segundos.
# El intento 609 tardó 0.1790609359741211 segundos.
# El intento 610 tardó 0.11057329177856445 segundos.
# El intento 611 tardó 0.20206403732299805 segundos.
# El intento 612 tardó 0.14459586143493652 segundos.
# El intento 613 tardó 0.14714312553405762 segundos.
# El intento 614 tardó 0.15955305099487305 segundos.
# El intento 615 tardó 0.15724825859069824 segundos.
# El intento 616 tardó 0.16152071952819824 segundos.
# El intento 617 tardó 0.2537996768951416 segundos.
# El intento 618 tardó 0.10751771926879883 segundos.
# El intento 619 tardó 0.1851212978363037 segundos.
# El intento 620 tardó 0.12455868721008301 segundos.
# El intento 621 tardó 0.1195366382598877 segundos.
# El intento 622 tardó 0.13307929039001465 segundos.
# El intento 623 tardó 0.13955402374267578 segundos.
# El intento 624 tardó 0.14818644523620605 segundos.
# El intento 625 tardó 0.15715742111206055 segundos.
# El intento 626 tardó 0.1533045768737793 segundos.
# El intento 627 tardó 0.17760181427001953 segundos.
# El intento 628 tardó 0.1707172393798828 segundos.
# El intento 629 tardó 0.24766826629638672 segundos.
# El intento 630 tardó 0.09200739860534668 segundos.
# El intento 631 tardó 0.18603944778442383 segundos.
# El intento 632 tardó 0.12490344047546387 segundos.
# El intento 633 tardó 0.15121912956237793 segundos.
# El intento 634 tardó 0.21406102180480957 segundos.
# El intento 635 tardó 0.1372673511505127 segundos.
# El intento 636 tardó 0.1535491943359375 segundos.
# El intento 637 tardó 0.13755249977111816 segundos.
# El intento 638 tardó 0.2613396644592285 segundos.
# El intento 639 tardó 0.3838925361633301 segundos.
# El intento 640 tardó 0.2160496711730957 segundos.
# El intento 641 tardó 0.3017086982727051 segundos.
# El intento 642 tardó 0.4211430549621582 segundos.
# El intento 643 tardó 0.33266663551330566 segundos.
# El intento 644 tardó 0.46268391609191895 segundos.
# El intento 645 tardó 0.37109971046447754 segundos.
# El intento 646 tardó 0.43712568283081055 segundos.
# El intento 647 tardó 0.12066793441772461 segundos.
# El intento 648 tardó 0.26108813285827637 segundos.
# El intento 649 tardó 0.18207883834838867 segundos.
# El intento 650 tardó 0.2236940860748291 segundos.
# El intento 651 tardó 0.1601250171661377 segundos.
# El intento 652 tardó 0.19420504570007324 segundos.
# El intento 653 tardó 0.3302192687988281 segundos.
# El intento 654 tardó 0.2108173370361328 segundos.
# El intento 655 tardó 0.1972048282623291 segundos.
# El intento 656 tardó 0.2320849895477295 segundos.
# El intento 657 tardó 0.23250508308410645 segundos.
# El intento 658 tardó 0.27861595153808594 segundos.
# El intento 659 tardó 0.21608424186706543 segundos.
# El intento 660 tardó 0.23822665214538574 segundos.
# El intento 661 tardó 0.2588808536529541 segundos.
# El intento 662 tardó 0.22913837432861328 segundos.
# El intento 663 tardó 0.295396089553833 segundos.
# El intento 664 tardó 0.2689015865325928 segundos.
# El intento 665 tardó 0.2322831153869629 segundos.
# El intento 666 tardó 0.21525979042053223 segundos.
# El intento 667 tardó 0.36521339416503906 segundos.
# El intento 668 tardó 0.326570987701416 segundos.
# El intento 669 tardó 0.3198390007019043 segundos.
# El intento 670 tardó 0.32567524909973145 segundos.
# El intento 671 tardó 0.34363222122192383 segundos.
# El intento 672 tardó 0.3612821102142334 segundos.
# El intento 673 tardó 0.38775181770324707 segundos.
# El intento 674 tardó 0.44144630432128906 segundos.
# El intento 675 tardó 0.47279977798461914 segundos.
# El intento 676 tardó 0.4292740821838379 segundos.
# El intento 677 tardó 0.46962618827819824 segundos.
# El intento 678 tardó 0.511427640914917 segundos.
# El intento 679 tardó 0.09429311752319336 segundos.
# El intento 680 tardó 0.4742085933685303 segundos.
# El intento 681 tardó 0.20306682586669922 segundos.
# El intento 682 tardó 0.14365363121032715 segundos.
# El intento 683 tardó 0.1501452922821045 segundos.
# El intento 684 tardó 0.14107751846313477 segundos.
# El intento 685 tardó 0.2430586814880371 segundos.
# El intento 686 tardó 0.16703486442565918 segundos.
# El intento 687 tardó 0.09308862686157227 segundos.
# El intento 688 tardó 0.10951471328735352 segundos.
# El intento 689 tardó 0.12055492401123047 segundos.
# El intento 690 tardó 0.21204853057861328 segundos.
# El intento 691 tardó 0.13161134719848633 segundos.
# El intento 692 tardó 0.24372005462646484 segundos.
# El intento 693 tardó 0.15741443634033203 segundos.
# El intento 694 tardó 0.15089130401611328 segundos.
# El intento 695 tardó 0.14770174026489258 segundos.
# El intento 696 tardó 0.17703795433044434 segundos.
# El intento 697 tardó 0.17832541465759277 segundos.
# El intento 698 tardó 0.19317865371704102 segundos.
# El intento 699 tardó 0.18513274192810059 segundos.
# El intento 700 tardó 0.2432410717010498 segundos.
# El intento 701 tardó 0.29261183738708496 segundos.
# El intento 702 tardó 0.2350311279296875 segundos.
# El intento 703 tardó 0.2327108383178711 segundos.
# El intento 704 tardó 0.3730735778808594 segundos.
# El intento 705 tardó 0.29622817039489746 segundos.
# El intento 706 tardó 0.25463151931762695 segundos.
# El intento 707 tardó 0.2686793804168701 segundos.
# El intento 708 tardó 0.40520286560058594 segundos.
# El intento 709 tardó 0.36362552642822266 segundos.
# El intento 710 tardó 0.37713050842285156 segundos.
# El intento 711 tardó 0.4154198169708252 segundos.
# El intento 712 tardó 0.46268129348754883 segundos.
# El intento 713 tardó 0.0896759033203125 segundos.
# El intento 714 tardó 0.22913432121276855 segundos.
# El intento 715 tardó 0.10854864120483398 segundos.
# El intento 716 tardó 0.10551047325134277 segundos.
# El intento 717 tardó 0.1540822982788086 segundos.
# El intento 718 tardó 0.08762669563293457 segundos.
# El intento 719 tardó 0.22705531120300293 segundos.
# El intento 720 tardó 0.14668488502502441 segundos.
# El intento 721 tardó 0.14713525772094727 segundos.
# El intento 722 tardó 0.16309046745300293 segundos.
# El intento 723 tardó 0.17263078689575195 segundos.
# El intento 724 tardó 0.09661650657653809 segundos.
# El intento 725 tardó 0.10162806510925293 segundos.
# El intento 726 tardó 0.20703577995300293 segundos.
# El intento 727 tardó 0.10364460945129395 segundos.
# El intento 728 tardó 0.10468339920043945 segundos.
# El intento 729 tardó 0.17518281936645508 segundos.
# El intento 730 tardó 0.10567998886108398 segundos.
# El intento 731 tardó 0.13516688346862793 segundos.
# El intento 732 tardó 0.1345517635345459 segundos.
# El intento 733 tardó 0.12943577766418457 segundos.
# El intento 734 tardó 0.139265775680542 segundos.
# El intento 735 tardó 0.12364745140075684 segundos.
# El intento 736 tardó 0.14560818672180176 segundos.
# El intento 737 tardó 0.1353440284729004 segundos.
# El intento 738 tardó 0.14465045928955078 segundos.
# El intento 739 tardó 0.1483020782470703 segundos.
# El intento 740 tardó 0.21227788925170898 segundos.
# El intento 741 tardó 0.17568397521972656 segundos.
# El intento 742 tardó 0.18806743621826172 segundos.
# El intento 743 tardó 0.18202614784240723 segundos.
# El intento 744 tardó 0.22926545143127441 segundos.
# El intento 745 tardó 0.3162262439727783 segundos.
# El intento 746 tardó 0.20028352737426758 segundos.
# El intento 747 tardó 0.2309882640838623 segundos.
# El intento 748 tardó 0.3887655735015869 segundos.
# El intento 749 tardó 0.27149105072021484 segundos.
# El intento 750 tardó 0.2510378360748291 segundos.
# El intento 751 tardó 0.3473992347717285 segundos.
# El intento 752 tardó 0.093231201171875 segundos.
# El intento 753 tardó 0.24652981758117676 segundos.
# El intento 754 tardó 0.09650969505310059 segundos.
# El intento 755 tardó 0.09850955009460449 segundos.
# El intento 756 tardó 0.1363234519958496 segundos.
# El intento 757 tardó 0.10550904273986816 segundos.
# El intento 758 tardó 0.1095128059387207 segundos.
# El intento 759 tardó 0.11451506614685059 segundos.
# El intento 760 tardó 0.14703869819641113 segundos.
# El intento 761 tardó 0.11762857437133789 segundos.
# El intento 762 tardó 0.16204142570495605 segundos.
# El intento 763 tardó 0.15351605415344238 segundos.
# El intento 764 tardó 0.15265750885009766 segundos.
# El intento 765 tardó 0.17803239822387695 segundos.
# El intento 766 tardó 0.1674637794494629 segundos.
# El intento 767 tardó 0.13904333114624023 segundos.
# El intento 768 tardó 0.09951567649841309 segundos.
# El intento 769 tardó 0.11151361465454102 segundos.
# El intento 770 tardó 0.11951828002929688 segundos.
# El intento 771 tardó 0.12328553199768066 segundos.
# El intento 772 tardó 0.2039659023284912 segundos.
# El intento 773 tardó 0.1760237216949463 segundos.
# El intento 774 tardó 0.21104216575622559 segundos.
# El intento 775 tardó 0.17960667610168457 segundos.
# El intento 776 tardó 0.27558398246765137 segundos.
# El intento 777 tardó 0.3285815715789795 segundos.
# El intento 778 tardó 0.30557727813720703 segundos.
# El intento 779 tardó 0.09751582145690918 segundos.
# El intento 780 tardó 0.10052347183227539 segundos.
# El intento 781 tardó 0.12052249908447266 segundos.
# El intento 782 tardó 0.10752105712890625 segundos.
# El intento 783 tardó 0.11751914024353027 segundos.
# El intento 784 tardó 0.25357770919799805 segundos.
# El intento 785 tardó 0.14352202415466309 segundos.
# El intento 786 tardó 0.299572229385376 segundos.
# El intento 787 tardó 0.35086941719055176 segundos.
# El intento 788 tardó 0.28063273429870605 segundos.
# El intento 789 tardó 0.2372417449951172 segundos.
# El intento 790 tardó 0.283689022064209 segundos.
# El intento 791 tardó 0.09661030769348145 segundos.
# El intento 792 tardó 0.09250998497009277 segundos.
# El intento 793 tardó 0.0925130844116211 segundos.
# El intento 794 tardó 0.10251307487487793 segundos.
# El intento 795 tardó 0.09150910377502441 segundos.
# El intento 796 tardó 0.0945136547088623 segundos.
# El intento 797 tardó 0.09551572799682617 segundos.
# El intento 798 tardó 0.09250831604003906 segundos.
# El intento 799 tardó 0.11316227912902832 segundos.
# El intento 800 tardó 0.15752077102661133 segundos.
# El intento 801 tardó 0.12454891204833984 segundos.
# El intento 802 tardó 0.10777997970581055 segundos.
# El intento 803 tardó 0.11365318298339844 segundos.
# El intento 804 tardó 0.11760401725769043 segundos.
# El intento 805 tardó 0.11265254020690918 segundos.
# El intento 806 tardó 0.1236116886138916 segundos.
# El intento 807 tardó 0.21416187286376953 segundos.
# El intento 808 tardó 0.1401987075805664 segundos.
# El intento 809 tardó 0.1970829963684082 segundos.
# El intento 810 tardó 0.1506814956665039 segundos.
# El intento 811 tardó 0.1853013038635254 segundos.
# El intento 812 tardó 0.15989398956298828 segundos.
# El intento 813 tardó 0.22722363471984863 segundos.
# El intento 814 tardó 0.1791691780090332 segundos.
# El intento 815 tardó 0.292680025100708 segundos.
# El intento 816 tardó 0.29764795303344727 segundos.
# El intento 817 tardó 0.23802685737609863 segundos.
# El intento 818 tardó 0.26488757133483887 segundos.
# El intento 819 tardó 0.4111349582672119 segundos.
# El intento 820 tardó 0.3176915645599365 segundos.
# El intento 821 tardó 0.28159022331237793 segundos.
# El intento 822 tardó 0.2646450996398926 segundos.
# El intento 823 tardó 0.30848240852355957 segundos.
# El intento 824 tardó 0.43662142753601074 segundos.
# El intento 825 tardó 0.39607882499694824 segundos.
# El intento 826 tardó 0.37369513511657715 segundos.
# El intento 827 tardó 0.41712117195129395 segundos.
# El intento 828 tardó 0.2640364170074463 segundos.
# El intento 829 tardó 0.2836284637451172 segundos.
# El intento 830 tardó 0.32976222038269043 segundos.
# El intento 831 tardó 0.299663782119751 segundos.
# El intento 832 tardó 0.2745509147644043 segundos.
# El intento 833 tardó 0.25653529167175293 segundos.
# El intento 834 tardó 0.27991580963134766 segundos.
# El intento 835 tardó 0.43327903747558594 segundos.
# El intento 836 tardó 0.3814964294433594 segundos.
# El intento 837 tardó 0.3436872959136963 segundos.
# El intento 838 tardó 0.3630256652832031 segundos.
# El intento 839 tardó 0.36258959770202637 segundos.
# El intento 840 tardó 0.3451406955718994 segundos.
# El intento 841 tardó 0.3547215461730957 segundos.
# El intento 842 tardó 0.4235970973968506 segundos.
# El intento 843 tardó 0.42022132873535156 segundos.
# El intento 844 tardó 0.5375881195068359 segundos.
# El intento 845 tardó 0.8162782192230225 segundos.
# El intento 846 tardó 0.5152301788330078 segundos.
# El intento 847 tardó 0.4927661418914795 segundos.
# El intento 848 tardó 0.5421180725097656 segundos.
# El intento 849 tardó 0.5196084976196289 segundos.
# El intento 850 tardó 0.60762619972229 segundos.
# El intento 851 tardó 0.6675477027893066 segundos.
# El intento 852 tardó 0.5108251571655273 segundos.
# El intento 853 tardó 0.6185867786407471 segundos.
# El intento 854 tardó 0.8293948173522949 segundos.
# El intento 855 tardó 0.6357717514038086 segundos.
# El intento 856 tardó 0.8262965679168701 segundos.
# El intento 857 tardó 0.13760614395141602 segundos.
# El intento 858 tardó 0.10454225540161133 segundos.
# El intento 859 tardó 0.10720276832580566 segundos.
# El intento 860 tardó 0.1015167236328125 segundos.
# El intento 861 tardó 0.11664843559265137 segundos.
# El intento 862 tardó 0.10947799682617188 segundos.
# El intento 863 tardó 0.1385200023651123 segundos.
# El intento 864 tardó 0.14201951026916504 segundos.
# El intento 865 tardó 0.164536714553833 segundos.
# El intento 866 tardó 0.1477062702178955 segundos.
# El intento 867 tardó 0.19601655006408691 segundos.
# El intento 868 tardó 0.23303771018981934 segundos.
# El intento 869 tardó 0.24306321144104004 segundos.
# El intento 870 tardó 0.2531309127807617 segundos.
# El intento 871 tardó 0.24404311180114746 segundos.
# El intento 872 tardó 0.28356504440307617 segundos.
# El intento 873 tardó 0.35323572158813477 segundos.
# El intento 874 tardó 0.31311464309692383 segundos.
# El intento 875 tardó 0.3304624557495117 segundos.
# El intento 876 tardó 0.36742186546325684 segundos.
# El intento 877 tardó 0.33956336975097656 segundos.
# El intento 878 tardó 0.3400897979736328 segundos.
# El intento 879 tardó 0.3437924385070801 segundos.
# El intento 880 tardó 0.3299405574798584 segundos.
# El intento 881 tardó 0.33408117294311523 segundos.
# El intento 882 tardó 0.4080488681793213 segundos.
# El intento 883 tardó 0.3955049514770508 segundos.
# El intento 884 tardó 0.3913536071777344 segundos.
# El intento 885 tardó 0.524773120880127 segundos.
# El intento 886 tardó 0.4174668788909912 segundos.
# El intento 887 tardó 0.46814870834350586 segundos.
# El intento 888 tardó 0.45742344856262207 segundos.
# El intento 889 tardó 0.500901460647583 segundos.
# El intento 890 tardó 0.49796152114868164 segundos.
# El intento 891 tardó 0.5224859714508057 segundos.
# El intento 892 tardó 0.5131714344024658 segundos.
# El intento 893 tardó 0.5578866004943848 segundos.
# El intento 894 tardó 0.601578950881958 segundos.
# El intento 895 tardó 0.6192758083343506 segundos.
# El intento 896 tardó 0.6159062385559082 segundos.
# El intento 897 tardó 0.68672776222229 segundos.
# El intento 898 tardó 0.6862099170684814 segundos.
# El intento 899 tardó 0.626448392868042 segundos.
# El intento 900 tardó 0.08705472946166992 segundos.
# El intento 901 tardó 0.09364771842956543 segundos.
# El intento 902 tardó 0.10155797004699707 segundos.
# El intento 903 tardó 0.103668212890625 segundos.
# El intento 904 tardó 0.11210489273071289 segundos.
# El intento 905 tardó 0.12958860397338867 segundos.
# El intento 906 tardó 0.12245869636535645 segundos.
# El intento 907 tardó 0.12760591506958008 segundos.
# El intento 908 tardó 0.13420629501342773 segundos.
# El intento 909 tardó 0.18169903755187988 segundos.
# El intento 910 tardó 0.27611470222473145 segundos.
# El intento 911 tardó 0.28351259231567383 segundos.
# El intento 912 tardó 0.3005330562591553 segundos.
# El intento 913 tardó 0.2868514060974121 segundos.
# El intento 914 tardó 0.3205387592315674 segundos.
# El intento 915 tardó 0.3270540237426758 segundos.
# El intento 916 tardó 0.32940149307250977 segundos.
# El intento 917 tardó 0.3629276752471924 segundos.
# El intento 918 tardó 0.39923691749572754 segundos.
# El intento 919 tardó 0.4032418727874756 segundos.
# El intento 920 tardó 0.39498329162597656 segundos.
# El intento 921 tardó 0.45247936248779297 segundos.
# El intento 922 tardó 0.43729281425476074 segundos.
# El intento 923 tardó 0.42078089714050293 segundos.
# El intento 924 tardó 0.4043242931365967 segundos.
# El intento 925 tardó 0.43297362327575684 segundos.
# El intento 926 tardó 0.4285132884979248 segundos.
# El intento 927 tardó 0.4393038749694824 segundos.
# El intento 928 tardó 0.4325869083404541 segundos.
# El intento 929 tardó 0.5312581062316895 segundos.
# El intento 930 tardó 0.43028831481933594 segundos.
# El intento 931 tardó 0.4879016876220703 segundos.
# El intento 932 tardó 0.4656698703765869 segundos.
# El intento 933 tardó 0.4680171012878418 segundos.
# El intento 934 tardó 0.5260496139526367 segundos.
# El intento 935 tardó 0.5263607501983643 segundos.
# El intento 936 tardó 0.5478579998016357 segundos.
# El intento 937 tardó 0.5506167411804199 segundos.
# El intento 938 tardó 0.5631520748138428 segundos.
# El intento 939 tardó 0.5627613067626953 segundos.
# El intento 940 tardó 0.7212069034576416 segundos.
# El intento 941 tardó 0.6619632244110107 segundos.
# El intento 942 tardó 0.6806411743164062 segundos.
# El intento 943 tardó 0.5684700012207031 segundos.
# El intento 944 tardó 0.5814237594604492 segundos.
# El intento 945 tardó 0.556342363357544 segundos.
# El intento 946 tardó 0.5839729309082031 segundos.
# El intento 947 tardó 0.6856870651245117 segundos.
# El intento 948 tardó 0.6320943832397461 segundos.
# ...
# El intento 5037 tardó 1.5556094646453857 segundos.
# El intento 5038 tardó 1.6215789318084717 segundos.
# El intento 5039 tardó 1.8076751232147217 segundos.
# El intento 5040 tardó 1.7270441055297852 segundos.
# El intento 5041 tardó 2.023730754852295 segundos.
# El intento 5042 tardó 1.949692964553833 segundos.
# El intento 5043 tardó 0.8537440299987793 segundos.
# El intento 5044 tardó 0.916454553604126 segundos.
# El intento 5045 tardó 1.7701411247253418 segundos.
# El intento 5046 tardó 2.1112606525421143 segundos.
# El intento 5047 tardó 1.6891064643859863 segundos.
# El intento 5048 tardó 1.7406566143035889 segundos.
# El intento 5049 tardó 1.7906320095062256 segundos.
# El intento 5050 tardó 1.9922220706939697 segundos.
# El intento 5051 tardó 2.3338897228240967 segundos.
# El intento 5052 tardó 1.9642109870910645 segundos.
# El intento 5053 tardó 1.635082483291626 segundos.
# El intento 5054 tardó 1.6931965351104736 segundos.
# El intento 5055 tardó 1.6006321907043457 segundos.
# El intento 5056 tardó 1.6716415882110596 segundos.
# El intento 5057 tardó 1.576608419418335 segundos.
# El intento 5058 tardó 1.7601594924926758 segundos.
# El intento 5059 tardó 1.7044448852539062 segundos.
# El intento 5060 tardó 1.6406824588775635 segundos.
# El intento 5061 tardó 0.7792356014251709 segundos.
# El intento 5062 tardó 0.8173017501831055 segundos.
# El intento 5063 tardó 0.7211673259735107 segundos.
# El intento 5064 tardó 0.6556620597839355 segundos.
# El intento 5065 tardó 0.7148439884185791 segundos.
# El intento 5066 tardó 0.6811838150024414 segundos.
# El intento 5067 tardó 0.5777032375335693 segundos.
# El intento 5068 tardó 0.6037082672119141 segundos.
# El intento 5069 tardó 0.5956554412841797 segundos.
# El intento 5070 tardó 0.621619462966919 segundos.
# El intento 5071 tardó 0.6277022361755371 segundos.
# El intento 5072 tardó 0.6859221458435059 segundos.
# El intento 5073 tardó 0.6703531742095947 segundos.
# El intento 5074 tardó 0.7741479873657227 segundos.
# El intento 5075 tardó 0.8192994594573975 segundos.
# El intento 5076 tardó 0.6506047248840332 segundos.
# El intento 5077 tardó 0.7869057655334473 segundos.
# El intento 5078 tardó 0.734882116317749 segundos.
# El intento 5079 tardó 0.7510380744934082 segundos.
# El intento 5080 tardó 0.6330487728118896 segundos.
# El intento 5081 tardó 1.3073198795318604 segundos.
# El intento 5082 tardó 0.8040280342102051 segundos.
# El intento 5083 tardó 0.7160611152648926 segundos.
# El intento 5084 tardó 0.8686964511871338 segundos.
# El intento 5085 tardó 0.7668087482452393 segundos.
# El intento 5086 tardó 0.8790621757507324 segundos.
# El intento 5087 tardó 1.0707907676696777 segundos.
# El intento 5088 tardó 0.7837352752685547 segundos.
# El intento 5089 tardó 0.8073432445526123 segundos.
# El intento 5090 tardó 0.7430055141448975 segundos.
# El intento 5091 tardó 0.5490694046020508 segundos.
# El intento 5092 tardó 0.6313526630401611 segundos.
# El intento 5093 tardó 0.5782477855682373 segundos.
# El intento 5094 tardó 0.5837600231170654 segundos.
# El intento 5095 tardó 0.628239631652832 segundos.
# El intento 5096 tardó 0.6381964683532715 segundos.
# El intento 5097 tardó 0.7847537994384766 segundos.
# El intento 5098 tardó 0.7119865417480469 segundos.
# El intento 5099 tardó 0.8509795665740967 segundos.
# El intento 5100 tardó 0.6372830867767334 segundos.
# El intento 5101 tardó 0.6470122337341309 segundos.
# El intento 5102 tardó 0.7261319160461426 segundos.
# El intento 5103 tardó 0.6352057456970215 segundos.
# El intento 5104 tardó 0.682471752166748 segundos.
# El intento 5105 tardó 0.6630463600158691 segundos.
# El intento 5106 tardó 0.6366620063781738 segundos.
# El intento 5107 tardó 0.6471736431121826 segundos.
# El intento 5108 tardó 0.6257812976837158 segundos.
# El intento 5109 tardó 0.6236841678619385 segundos.
# El intento 5110 tardó 0.6646392345428467 segundos.
# El intento 5111 tardó 0.6877200603485107 segundos.
# El intento 5112 tardó 0.6694900989532471 segundos.
# El intento 5113 tardó 1.0072054862976074 segundos.
# El intento 5114 tardó 1.272862434387207 segundos.
# El intento 5115 tardó 0.7434349060058594 segundos.
# El intento 5116 tardó 0.6847515106201172 segundos.
# El intento 5117 tardó 0.7257509231567383 segundos.
# El intento 5118 tardó 0.6562092304229736 segundos.
# El intento 5119 tardó 0.6661520004272461 segundos.
# El intento 5120 tardó 0.6330621242523193 segundos.
# El intento 5121 tardó 0.6272566318511963 segundos.
# El intento 5122 tardó 0.6298165321350098 segundos.
# El intento 5123 tardó 0.6499831676483154 segundos.
# El intento 5124 tardó 0.68009352684021 segundos.
# El intento 5125 tardó 0.6573324203491211 segundos.
# El intento 5126 tardó 0.7259466648101807 segundos.
# El intento 5127 tardó 0.8790969848632812 segundos.
# El intento 5128 tardó 1.0850636959075928 segundos.
# El intento 5129 tardó 0.8463995456695557 segundos.
# El intento 5130 tardó 0.669644832611084 segundos.
# El intento 5131 tardó 0.7130241394042969 segundos.
# El intento 5132 tardó 0.6686983108520508 segundos.
# El intento 5133 tardó 0.5984139442443848 segundos.
# El intento 5134 tardó 0.6498894691467285 segundos.
# El intento 5135 tardó 0.7321562767028809 segundos.
# El intento 5136 tardó 0.6734275817871094 segundos.
# El intento 5137 tardó 0.8354184627532959 segundos.
# El intento 5138 tardó 0.7961795330047607 segundos.
# El intento 5139 tardó 0.9039726257324219 segundos.
# El intento 5140 tardó 1.0820963382720947 segundos.
# El intento 5141 tardó 0.8816440105438232 segundos.
# El intento 5142 tardó 0.8344917297363281 segundos.
# El intento 5143 tardó 0.8140695095062256 segundos.
# El intento 5144 tardó 0.790926456451416 segundos.
# El intento 5145 tardó 0.8168196678161621 segundos.
# El intento 5146 tardó 0.5718352794647217 segundos.
# El intento 5147 tardó 0.6259009838104248 segundos.
# El intento 5148 tardó 0.5840096473693848 segundos.
# El intento 5149 tardó 0.6238231658935547 segundos.
# El intento 5150 tardó 0.6036975383758545 segundos.
# El intento 5151 tardó 0.5619235038757324 segundos.
# El intento 5152 tardó 0.5783779621124268 segundos.
# El intento 5153 tardó 0.5995633602142334 segundos.
# El intento 5154 tardó 0.6560533046722412 segundos.
# El intento 5155 tardó 0.6743576526641846 segundos.
# El intento 5156 tardó 0.7015986442565918 segundos.
# El intento 5157 tardó 0.6809942722320557 segundos.
# El intento 5158 tardó 0.7120692729949951 segundos.
# El intento 5159 tardó 0.776655912399292 segundos.
# El intento 5160 tardó 0.6851761341094971 segundos.
# El intento 5161 tardó 0.6808981895446777 segundos.
# El intento 5162 tardó 0.7349059581756592 segundos.
# El intento 5163 tardó 0.81770920753479 segundos.
# El intento 5164 tardó 0.8530161380767822 segundos.
# El intento 5165 tardó 0.8503992557525635 segundos.
# El intento 5166 tardó 0.9448540210723877 segundos.
# El intento 5167 tardó 0.8926610946655273 segundos.
# El intento 5168 tardó 0.6653735637664795 segundos.
# El intento 5169 tardó 0.7594912052154541 segundos.
# El intento 5170 tardó 0.5931470394134521 segundos.
# El intento 5171 tardó 0.7078478336334229 segundos.
# El intento 5172 tardó 0.6245856285095215 segundos.
# El intento 5173 tardó 0.6224653720855713 segundos.
# El intento 5174 tardó 0.6346616744995117 segundos.
# El intento 5175 tardó 0.5926425457000732 segundos.
# El intento 5176 tardó 0.6052665710449219 segundos.
# El intento 5177 tardó 0.6037735939025879 segundos.
# El intento 5178 tardó 0.6648604869842529 segundos.
# El intento 5179 tardó 0.6449766159057617 segundos.
# El intento 5180 tardó 0.7057008743286133 segundos.
# El intento 5181 tardó 0.7011163234710693 segundos.
# El intento 5182 tardó 0.7922685146331787 segundos.
# El intento 5183 tardó 0.8406527042388916 segundos.
# El intento 5184 tardó 0.8285548686981201 segundos.
# El intento 5185 tardó 0.6430392265319824 segundos.
# El intento 5186 tardó 0.6056258678436279 segundos.
# El intento 5187 tardó 0.671898365020752 segundos.
# El intento 5188 tardó 0.6067206859588623 segundos.
# El intento 5189 tardó 0.5846619606018066 segundos.
# El intento 5190 tardó 0.6449041366577148 segundos.
# El intento 5191 tardó 0.5906143188476562 segundos.
# El intento 5192 tardó 0.615288257598877 segundos.
# El intento 5193 tardó 0.6396355628967285 segundos.
# El intento 5194 tardó 0.6811015605926514 segundos.
# El intento 5195 tardó 0.6155745983123779 segundos.
# El intento 5196 tardó 0.6999313831329346 segundos.
# El intento 5197 tardó 0.7151753902435303 segundos.
# El intento 5198 tardó 0.7720098495483398 segundos.
# El intento 5199 tardó 0.7973043918609619 segundos.
# El intento 5200 tardó 0.7970139980316162 segundos.
# El intento 5201 tardó 0.732633113861084 segundos.
# El intento 5202 tardó 0.7284736633300781 segundos.
# El intento 5203 tardó 0.6835670471191406 segundos.
# El intento 5204 tardó 0.7361342906951904 segundos.
# El intento 5205 tardó 0.7655117511749268 segundos.
# El intento 5206 tardó 0.7467920780181885 segundos.
# El intento 5207 tardó 0.7231788635253906 segundos.
# El intento 5208 tardó 0.6929492950439453 segundos.
# El intento 5209 tardó 0.6075823307037354 segundos.
# El intento 5210 tardó 0.7009637355804443 segundos.
# El intento 5211 tardó 0.609337329864502 segundos.
# El intento 5212 tardó 0.6999804973602295 segundos.
# El intento 5213 tardó 0.6769659519195557 segundos.
# El intento 5214 tardó 0.7224550247192383 segundos.
# El intento 5215 tardó 0.6990201473236084 segundos.
# El intento 5216 tardó 0.7966675758361816 segundos.
# El intento 5217 tardó 0.6203489303588867 segundos.
# El intento 5218 tardó 0.7156393527984619 segundos.
# El intento 5219 tardó 0.6944398880004883 segundos.
# El intento 5220 tardó 0.7104446887969971 segundos.
# El intento 5221 tardó 0.5665397644042969 segundos.
# El intento 5222 tardó 0.597520112991333 segundos.
# El intento 5223 tardó 0.6622910499572754 segundos.
# El intento 5224 tardó 0.772453784942627 segundos.
# El intento 5225 tardó 0.6889755725860596 segundos.
# El intento 5226 tardó 0.6873061656951904 segundos.
# El intento 5227 tardó 0.7335538864135742 segundos.
# El intento 5228 tardó 0.7466545104980469 segundos.
# El intento 5229 tardó 0.7516984939575195 segundos.
# El intento 5230 tardó 0.6575391292572021 segundos.
# El intento 5231 tardó 0.6010684967041016 segundos.
# El intento 5232 tardó 0.6046512126922607 segundos.
# El intento 5233 tardó 0.6215002536773682 segundos.
# El intento 5234 tardó 0.5729150772094727 segundos.
# El intento 5235 tardó 0.6851444244384766 segundos.
# El intento 5236 tardó 0.64267897605896 segundos.
# El intento 5237 tardó 0.6751949787139893 segundos.
# El intento 5238 tardó 0.6611087322235107 segundos.
# El intento 5239 tardó 0.6774132251739502 segundos.
# El intento 5240 tardó 0.6339399814605713 segundos.
# El intento 5241 tardó 0.627345085144043 segundos.
# El intento 5242 tardó 0.6496896743774414 segundos.
# El intento 5243 tardó 0.7259867191314697 segundos.
# El intento 5244 tardó 0.682795524597168 segundos.
# El intento 5245 tardó 0.6392996311187744 segundos.
# El intento 5246 tardó 0.7245752811431885 segundos.
# El intento 5247 tardó 0.6571474075317383 segundos.
# El intento 5248 tardó 0.6318364143371582 segundos.
# El intento 5249 tardó 0.633073091506958 segundos.
# El intento 5250 tardó 0.7240407466888428 segundos.
# El intento 5251 tardó 0.599611759185791 segundos.
# El intento 5252 tardó 0.6376333236694336 segundos.
# El intento 5253 tardó 0.5596311092376709 segundos.
# El intento 5254 tardó 0.6879103183746338 segundos.
# El intento 5255 tardó 0.6494956016540527 segundos.
# El intento 5256 tardó 0.5915834903717041 segundos.
# El intento 5257 tardó 0.6040294170379639 segundos.
# El intento 5258 tardó 0.6294047832489014 segundos.
# El intento 5259 tardó 0.7092230319976807 segundos.
# El intento 5260 tardó 0.719160795211792 segundos.
# El intento 5261 tardó 0.6830804347991943 segundos.
# El intento 5262 tardó 0.6192762851715088 segundos.
# El intento 5263 tardó 0.6931283473968506 segundos.
# El intento 5264 tardó 0.6487503051757812 segundos.
# El intento 5265 tardó 0.7006134986877441 segundos.
# El intento 5266 tardó 0.6931483745574951 segundos.
# El intento 5267 tardó 0.9092199802398682 segundos.
# El intento 5268 tardó 0.7435717582702637 segundos.
# El intento 5269 tardó 1.009690284729004 segundos.
# El intento 5270 tardó 1.1321282386779785 segundos.
# El intento 5271 tardó 0.8358173370361328 segundos.
# El intento 5272 tardó 0.8451337814331055 segundos.
# El intento 5273 tardó 0.8197042942047119 segundos.
# El intento 5274 tardó 0.7412455081939697 segundos.
# El intento 5275 tardó 0.730520486831665 segundos.
# El intento 5276 tardó 0.8103330135345459 segundos.
# El intento 5277 tardó 0.8292489051818848 segundos.
# El intento 5278 tardó 0.8248212337493896 segundos.
# El intento 5279 tardó 0.7573564052581787 segundos.
# El intento 5280 tardó 0.7938342094421387 segundos.
# El intento 5281 tardó 0.9602744579315186 segundos.
# El intento 5282 tardó 0.865994930267334 segundos.
# El intento 5283 tardó 0.6314854621887207 segundos.
# El intento 5284 tardó 0.6307263374328613 segundos.
# El intento 5285 tardó 0.6294565200805664 segundos.
# El intento 5286 tardó 0.6884853839874268 segundos.
# El intento 5287 tardó 0.7001237869262695 segundos.
# El intento 5288 tardó 0.5572509765625 segundos.
# El intento 5289 tardó 0.6266658306121826 segundos.
# El intento 5290 tardó 0.5921647548675537 segundos.
# El intento 5291 tardó 0.6116416454315186 segundos.
# El intento 5292 tardó 0.724876880645752 segundos.
# El intento 5293 tardó 0.6899964809417725 segundos.
# El intento 5294 tardó 0.7591359615325928 segundos.
# El intento 5295 tardó 0.5800070762634277 segundos.
# El intento 5296 tardó 0.6083981990814209 segundos.
# El intento 5297 tardó 0.6279428005218506 segundos.
# El intento 5298 tardó 0.6869714260101318 segundos.
# El intento 5299 tardó 0.6052463054656982 segundos.
# El intento 5300 tardó 0.686337947845459 segundos.
# El intento 5301 tardó 0.6758320331573486 segundos.
# El intento 5302 tardó 0.6362183094024658 segundos.
# El intento 5303 tardó 0.5451385974884033 segundos.
# El intento 5304 tardó 0.6155669689178467 segundos.
# El intento 5305 tardó 0.5792689323425293 segundos.
# El intento 5306 tardó 0.5702533721923828 segundos.
# El intento 5307 tardó 0.5729851722717285 segundos.
# El intento 5308 tardó 0.5776324272155762 segundos.
# El intento 5309 tardó 0.6250486373901367 segundos.
# El intento 5310 tardó 0.5803067684173584 segundos.
# El intento 5311 tardó 0.7360382080078125 segundos.
# El intento 5312 tardó 0.6565382480621338 segundos.
# El intento 5313 tardó 0.7424330711364746 segundos.
# El intento 5314 tardó 0.6336653232574463 segundos.
# El intento 5315 tardó 0.7220256328582764 segundos.
# El intento 5316 tardó 0.6194033622741699 segundos.
# El intento 5317 tardó 0.6645205020904541 segundos.
# El intento 5318 tardó 0.6233367919921875 segundos.
# El intento 5319 tardó 0.6005764007568359 segundos.
# El intento 5320 tardó 0.6130650043487549 segundos.
# El intento 5321 tardó 0.6161751747131348 segundos.
# El intento 5322 tardó 0.6731836795806885 segundos.
# El intento 5323 tardó 0.6632237434387207 segundos.
# El intento 5324 tardó 0.6490969657897949 segundos.
# El intento 5325 tardó 0.6046669483184814 segundos.
# El intento 5326 tardó 0.7433900833129883 segundos.
# El intento 5327 tardó 0.6932625770568848 segundos.
# El intento 5328 tardó 0.7806458473205566 segundos.
# El intento 5329 tardó 0.7200751304626465 segundos.
# El intento 5330 tardó 0.7508909702301025 segundos.
# El intento 5331 tardó 0.7657203674316406 segundos.
# El intento 5332 tardó 0.7430336475372314 segundos.
# El intento 5333 tardó 0.7324924468994141 segundos.
# El intento 5334 tardó 0.6227049827575684 segundos.
# El intento 5335 tardó 0.6504292488098145 segundos.
# El intento 5336 tardó 0.6907539367675781 segundos.
# El intento 5337 tardó 0.57955002784729 segundos.
# El intento 5338 tardó 0.6219921112060547 segundos.
# El intento 5339 tardó 0.5882995128631592 segundos.
# El intento 5340 tardó 0.7361288070678711 segundos.
# El intento 5341 tardó 0.6855568885803223 segundos.
# El intento 5342 tardó 0.7364997863769531 segundos.
# El intento 5343 tardó 0.6253933906555176 segundos.
# El intento 5344 tardó 0.7068343162536621 segundos.
# El intento 5345 tardó 0.6580319404602051 segundos.
# El intento 5346 tardó 0.6267011165618896 segundos.
# El intento 5347 tardó 0.6592817306518555 segundos.
# El intento 5348 tardó 0.5936965942382812 segundos.
# El intento 5349 tardó 0.6126432418823242 segundos.
# El intento 5350 tardó 0.5836548805236816 segundos.

# %%
features.to_csv("../Outputs/featuresOutput_percentil111.csv", decimal=".", sep=";", mode='w')
