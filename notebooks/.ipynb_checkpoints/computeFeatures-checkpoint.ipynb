# %%
import pandas as pd
from collections import OrderedDict
from datetime import datetime
import numpy as np
import json
import time
from sklearn.preprocessing import OneHotEncoder

import sys
sys.path.append('../python')
import userHistorial as uh
import ELO as elo
import timeLimitEvents as timeLimits

# %%
# Dataframe with all the events
dataEvents = pd.read_csv('E:/Documentos/PCEO/5/Informatica/TFG/datos/anonamyze_all_data_collection_v2.csv', sep=";")

# %%
# Dictionary with the average complete time of every puzzle
tiemposPuzzles = pd.read_csv('E:/Documentos/PCEO/5/Informatica/TFG/scripts/TFG-Informatica/Outputs/avgTimeByPuzzleOutput.csv', sep=";")

# %%
# Dictionary with the ELO difficulty of every puzzle

dict_elo_puzzles = {
    'Sandbox': 0.0,
    '1. One Box': 0.0,
    '2. Separated Boxes': 0.12,
    '3. Rotate a Pyramid': 0.24,
    '4. Match Silhouettes': 0.42,
    'Sugar Cones': 0.9,
    '8. Combine 2 Ramps': 0.57,
    '9. Scaling Round Objects': 0.57,
    'Square Cross-Sections': 0.99,
    'Bird Fez': 1.77,
    'Pi Henge': 1.26,
    '45-Degree Rotations': 0.78,
    'Pyramids are Strange': 1.29,
    'Boxes Obscure Spheres': 1.91,
    'Object Limits': 1.62,
    'Tetromino': 1.74,
    'Angled Silhouette': 1.35,
    'Stranger Shapes': 1.7,
    'Tall and Small': 1.73,
    '5. Removing Objects': 0.48,
    '6. Stretch a Ramp': 0.42,
    '7. Max 2 Boxes': 0.6,
    'Ramp Up and Can It': 1.73,
    'More Than Meets Your Eye': 1.2,
    'Bear Market': 3.0,
    'Not Bird': 2.13,
    'Warm Up': 0.6,
    'Unnecessary': 1.74,
    'Zzz': 1.81,
    'Bull Market': 2.98,
    'Few Clues': 1.93,
    'Orange Dance': 2.37
}

# %%
# Every puzzle difficulty
difficultyMapping = ['Sandbox~0.000001','1. One Box~0.000002', '2. Separated Boxes~0.111127', '3. Rotate a Pyramid~0.083447', '4. Match Silhouettes~0.061887', '5. Removing Objects~0.106021', '6. Stretch a Ramp~0.107035', '7. Max 2 Boxes~0.078039', '8. Combine 2 Ramps~0.068608', '9. Scaling Round Objects~0.128647',
                     'Square Cross-Sections~0.199714', 'Bird Fez~0.156674', 'Pi Henge~0.067346', '45-Degree Rotations~0.096715',  'Pyramids are Strange~0.179600', 'Boxes Obscure Spheres~0.266198', 'Object Limits~0.257177', 'Not Bird~0.260197', 'Angled Silhouette~0.147673',
                     'Warm Up~0.183971','Tetromino~0.226869', 'Stranger Shapes~0.283971', 'Sugar Cones~0.085909', 'Tall and Small~0.266869', 'Ramp Up and Can It~0.206271', 'More Than Meets Your Eye~0.192319', 'Unnecessary~0.76', 'Zzz~0.234035', 'Bull Market~0.358579', 'Few Clues~0.324041', 'Orange Dance~0.647731', 'Bear Market~1.000000']


typeMapping = ['Sandbox~SAND', '1. One Box~Tutorial', '2. Separated Boxes~Tutorial', '3. Rotate a Pyramid~Tutorial', '4. Match Silhouettes~Tutorial', '5. Removing Objects~Tutorial', '6. Stretch a Ramp~Tutorial', '7. Max 2 Boxes~Tutorial', '8. Combine 2 Ramps~Tutorial', '9. Scaling Round Objects~Tutorial',
               'Square Cross-Sections~Easy Puzzles', 'Bird Fez~Easy Puzzles', 'Pi Henge~Easy Puzzles', '45-Degree Rotations~Easy Puzzles',  'Pyramids are Strange~Easy Puzzles', 'Boxes Obscure Spheres~Easy Puzzles', 'Object Limits~Easy Puzzles', 'Not Bird~Easy Puzzles', 'Angled Silhouette~Easy Puzzles',
               'Warm Up~Hard Puzzles','Tetromino~Hard Puzzles', 'Stranger Shapes~Hard Puzzles', 'Sugar Cones~Hard Puzzles', 'Tall and Small~Hard Puzzles', 'Ramp Up and Can It~Hard Puzzles', 'More Than Meets Your Eye~Hard Puzzles', 'Unnecessary~Hard Puzzles', 'Zzz~Hard Puzzles', 'Bull Market~Hard Puzzles', 'Few Clues~Hard Puzzles', 'Orange Dance~Hard Puzzles', 'Bear Market~Hard Puzzles']

# Dictionary with the difficulty of every puzzle
difficultyPuzzles = dict()

for puzzle in difficultyMapping:
    desc = puzzle.split("~")
    difficultyPuzzles[desc[0]] = float(desc[1])


tutorialPuzzles = []

for puzzle in typeMapping:
    desc = puzzle.split("~")
    if(desc[1] == 'Tutorial'):
        tutorialPuzzles.append(desc[0])

advancedPuzzles = []

for puzzle in typeMapping:
    desc = puzzle.split("~")
    if(desc[1] == 'Hard Puzzles'):
        advancedPuzzles.append(desc[0])

intermediatePuzzles = []

for puzzle in typeMapping:
    desc = puzzle.split("~")
    if(desc[1] == 'Easy Puzzles'):
        intermediatePuzzles.append(desc[0])

allPuzzles = []
for puzzle in typeMapping:
    desc = puzzle.split("~")
    allPuzzles.append(desc[0])


def computeFeatures(dataEvents,percentil=1, user_objective='all', group_objective = 'all'):

    # Guardar el instante inicial
    inicio = time.time()

    #copia
    copia = dataEvents.copy()

    dataEvents['time'] = pd.to_datetime(dataEvents['time'])
    dataEvents = dataEvents.sort_values('time')

    #iterates in the groups and users of the data
    dataEvents['group'] = [json.loads(x)['group'] if 'group' in json.loads(x).keys() else '' for x in
                           dataEvents['data']]
    dataEvents['user'] = [json.loads(x)['user'] if 'user' in json.loads(x).keys() else '' for x in dataEvents['data']]
    dataEvents['task_id'] = [json.loads(x)['task_id'] if 'task_id' in json.loads(x).keys() else '' for x in
                             dataEvents['data']]

    # removing those rows where we dont have a group and a user that is not guest
    dataEvents = dataEvents[
        ((dataEvents['group'] != '') & (dataEvents['user'] != '') & (dataEvents['user'] != 'guest'))]
    dataEvents['group_user_id'] = dataEvents['group'] + '~' + dataEvents['user']
    dataEvents['group_user_task_id'] = dataEvents['group'] + '~' + dataEvents['user'] + '~' + dataEvents['task_id']

    # filtering to only take the user passed as argument
    #if(user != 'all'):
    #    dataEvents = dataEvents[dataEvents['user'].isin(user)]
    if(group_objective != 'all'):
        dataEvents = dataEvents[dataEvents['group'].isin(group_objective)]

    # the data is grouped by the necessary variables
    activity_by_user = dataEvents.groupby(['group_user_id']).agg({'id': 'count',
                                                                  'type': 'nunique'}).reset_index().rename(columns={'id': 'events',
                                                                                        'type': 'different_events'})



    # Data Cleaning
    #dataEvents['time'] = pd.to_datetime(dataEvents['time'])
    dataEvents = dataEvents.sort_values('time')

    typeEvents = ['ws-snapshot', 'ws-paint', 'ws-rotate_view', 'ws-move_shape', 'ws-rotate_shape', 'ws-scale_shape',
                  'ws-create_shape', 'ws-delete_shape', 'ws-undo_action', 'ws-redo_action', 'ws-check_solution']
    manipulationTypeEvents = ['ws-move_shape', 'ws-rotate_shape', 'ws-scale_shape', 'ws-create_shape',
                              'ws-delete_shape']

    #initialize the metrics
    activity_by_user['completed'] = np.nan
    activity_by_user['active_time'] = np.nan
    activity_by_user['n_events'] = np.nan
    activity_by_user['timestamp'] = np.nan

    for event in typeEvents:
        activity_by_user[event] = 0
#----------------------------------------------------------------------------------------------------------------------------------
    #initialize the data structures

    puzzleEvents = dict() #Diccionario que guarda para cada intento (alumno,puzzle,nintento) el número de eventos

    timePuzzle = dict() #Diccionario que guarda para cada intento el tiempo activo

    globalTypesEvents = dict() #Diccionario que guarda para cada intento el número de eventos de cada tipo

    n_attempts = dict() #Diccionario que guarda para cada el número de intentos

    completados = dict() #Diccionario que guarda para cada intento si se completó

    timestamp = dict() #Diccionario que guarda para cada intento el timestamp inicial

    percentilAtt = dict()
    percentilTime = dict() #Diccionarios que guardan un 90 para cada intento (creo)
    percentilAttValue = 90
    percentilTimeValue = 90

    breaksPuzzle = dict() #Diccionario que guarda para cada intento el número de breaks ( parones de 15 segundos )

    cumAttempts = OrderedDict() #Diccionario que guarda para cada intento, que número de intento gloabal es


    userCumAttempts = OrderedDict() #Diccionario que guarda para cada alumno cuantos intentos en total ha hecho


    prevReg = dict() #Diccionario que almacena para cada dupla alumno-puzzle, si se ha intentado anteriormente

    actualAtt = 0 #Variable global que lleva el contador de intentos global

    idComplete = dict() #Diccionario que guarda para cada intento si se finalizó

    attemptsAux = dict() #Doble diccionario que guarda para cada usuario y para cada puzzle el numero de intentos

    contCheckSol = dict() #Diccionario que guarda para cada intento el número de submits

    bestSubmit = dict() #Diccionario que guarda el mejor submit de cada intento

    manipulationEvents = dict() #Diccionario que guarda para cada intento el número de eventos de manipulacion

    userManipulationEvents = dict() #Creo que actualmente no se utiliza

    contManipulation = 0

    timeFirstCheck = dict() #Diccionario que guarda para cada intento el timestamp del primer submit

    timeSubExit = dict() #Diccionario que guarda para cada intento, el tiempo que ha pasado entre el primer submit y el exit

    timeCheckActual = dict() #Diccionario que guarda para cada intento el timestamp del último check

    timeBetweenSub = dict() #Diccionario que guarda para cada intento la media de tiempo entre cada submit
#---------------------------------------------------------------------------------------------------------------------------------
    for user in dataEvents['group_user_id'].unique():

        # Computing active time
        previousEvent = None
        theresHoldActivity = 60
        tiempoPercentil = 0

        user_events = dataEvents[dataEvents['group_user_id'] == user] #eventos del usuario
        user_puzzle_key = None
        userParc = None
        task_id = None
        initialTime = None
        prev_id = 1

        for enum, event in user_events.iterrows():

            # If it is the first event
            if (previousEvent is None):
                previousEvent = event
                continue

            if (event['type'] in ['ws-start_level']):

                #create id: group+user+task_id
                task_id = json.loads(event['data'])['task_id']

                if (user_puzzle_key not in timeSubExit.keys()):
                    timeSubExit[user_puzzle_key] = str(0)
                    timeBetweenSub[user_puzzle_key] = str(0)

                if (event['user'] not in userCumAttempts.keys()):
                    userCumAttempts[event['user']] = 0
                    actualAtt = 0
                    attemptsAux[event['user']] = dict()
                    timeCheckActual[event['user']] = 0

                if (event['user'] not in userManipulationEvents.keys()):
                    userManipulationEvents[event['user']] = 0


                if (task_id not in attemptsAux[event['user']].keys()): attemptsAux[event['user']][task_id] = 0

                user_puzzle_key = event['group'] + '~' + event[
                    'user'] + '~' + task_id  # + '~' + str(n_attempts[prev_id])
                if (user_puzzle_key not in prevReg.keys()):

                    prevReg[user_puzzle_key] = 1
                    user_puzzle_key = event['group'] + '~' + event['user'] + '~' + task_id + '~' + '1'
                    n_attempts[user_puzzle_key] = 1
                    attemptsAux[event['user']][task_id] = n_attempts[user_puzzle_key]

                else:

                    user_puzzle_key = event['group'] + '~' + event['user'] + '~' + task_id + '~' + str(
                        attemptsAux[event['user']][task_id])
                    n_attempts[user_puzzle_key] = attemptsAux[event['user']][task_id]

                key_split = user_puzzle_key.split('~')
                puzzleParc = key_split[2]
                userParc = key_split[1]

                tiemposPuzzle = tiemposPuzzles[tiemposPuzzles['puzzle']==puzzleParc].reset_index()
                if not tiemposPuzzle.empty:
                    tiempoPercentil =  round(tiemposPuzzle.loc[0,'avg_complete_time']*0.25*percentil,2)

                if (user_puzzle_key not in idComplete.keys()): idComplete[user_puzzle_key] = 0

                if (task_id not in attemptsAux[userParc].keys()): attemptsAux[userParc][task_id] = 0
                if (user_puzzle_key not in cumAttempts.keys()): cumAttempts[user_puzzle_key] = 1

                # initialize if the id is new
                if (user_puzzle_key not in puzzleEvents.keys()):

                    breaksPuzzle[user_puzzle_key] = 0
                    timestamp[user_puzzle_key] = 0
                    percentilAtt[user_puzzle_key] = percentilAttValue
                    percentilTime[user_puzzle_key] = percentilTimeValue
                    completados[user_puzzle_key] = 0
                    puzzleEvents[user_puzzle_key] = 1
                    timePuzzle[user_puzzle_key] = 0
                    contCheckSol[user_puzzle_key] = 0
                    bestSubmit[user_puzzle_key] = 0
                    manipulationEvents[user_puzzle_key] = 0
                    timeFirstCheck[user_puzzle_key] = 0

                    globalTypesEvents[user_puzzle_key] = dict()
                    for ev in typeEvents:
                        globalTypesEvents[user_puzzle_key][ev] = 0

                #timestamp
                if (event['type'] in 'ws-start_level'):
                    timestamp[user_puzzle_key] = event['time']

            # the event is not final event
            if (event['type'] not in ['ws-exit_to_menu', 'ws-disconnect', 'ws-create_user', 'ws-login_user']):

                #calculate the duration of the event
                delta_seconds = (event['time'] - previousEvent['time']).total_seconds()

                if ((delta_seconds < theresHoldActivity)):
                    timePuzzle[user_puzzle_key] += delta_seconds



                if (event['type'] in ['ws-puzzle_complete']): completados[user_puzzle_key] = 1



                if round((timePuzzle[user_puzzle_key]/60),2) < tiempoPercentil:

                    puzzleEvents[user_puzzle_key] += 1

                    #breaks
                    if ((delta_seconds > 15)):
                        breaksPuzzle[user_puzzle_key] += 1

                    #update event counters by type
                    if (event['type'] in typeEvents):
                        globalTypesEvents[user_puzzle_key][event['type']] += 1

                    if (globalTypesEvents[user_puzzle_key]['ws-check_solution'] == 1): timeFirstCheck[user_puzzle_key] = \
                        event['time']

                    if (event['type'] in manipulationTypeEvents):
                        manipulationEvents[user_puzzle_key] += 1

                    if (event['type'] == 'ws-check_solution'):
                        timeCheckActual[event['user']] = event['time']
                        contCheckSol[user_puzzle_key] += 1
                        dict_views = json.loads(event['data'])['correct']
                        corr = 0
                        for key in dict_views:
                            if key == True:
                                corr += 1
                        percentage_aux = (corr / len(dict_views))*100
                        if percentage_aux > bestSubmit[user_puzzle_key]:
                            bestSubmit[user_puzzle_key] = round(percentage_aux,2)






                previousEvent = event



            # the puzzle ends
            if (event['type'] in ['ws-exit_to_menu', 'ws-disconnect']):

                idComplete[user_puzzle_key] = 1

                #calculate the duration of the event
                delta_seconds = (event['time'] - previousEvent['time']).total_seconds()
                if ((delta_seconds < theresHoldActivity)):
                    timePuzzle[user_puzzle_key] += delta_seconds



                if round((timePuzzle[user_puzzle_key]/60),2) < tiempoPercentil:

                    puzzleEvents[user_puzzle_key] += 1

                    #breaks
                    if ((delta_seconds > 15)):
                        breaksPuzzle[user_puzzle_key] += 1


                if (completados[user_puzzle_key] == 0 and globalTypesEvents[user_puzzle_key]['ws-check_solution'] > 0):
                    timeSubExit[user_puzzle_key] = str(
                        round((event['time'] - timeFirstCheck[user_puzzle_key]).total_seconds(), 2))
                else:
                    timeSubExit[user_puzzle_key] = 'NA'

                if (globalTypesEvents[user_puzzle_key]['ws-check_solution'] == 0):
                    timeBetweenSub[user_puzzle_key] = 'NA'
                else:
                    timeBetweenSub[user_puzzle_key] = str(round(((timeCheckActual[event['user']] - timestamp[
                        user_puzzle_key]) / globalTypesEvents[user_puzzle_key]['ws-check_solution']).total_seconds(),
                                                                2))

                previousEvent = event

                userCumAttempts[userParc] += 1
                n_attempts[user_puzzle_key] += 1
                actualAtt += 1
                cumAttempts[user_puzzle_key] = actualAtt
                attemptsAux[userParc][task_id] = n_attempts[user_puzzle_key]


    # Guardar el instante final
    fin = time.time()

    # Calcular la diferencia en segundos
    diferencia = fin - inicio

    print("El proceso 1 tardó", diferencia, "segundos.")

    count = 0

    for i in puzzleEvents.keys():

        if(idComplete[i]==0):
            continue

        key_split = i.split('~')

        if(user_objective != 'all'):
            if not (key_split[1] in user_objective):
                continue
        if(group_objective != 'all'):
            if not (key_split[0] in group_objective):
                continue


        # recortamos los eventos hasta el timestamp inicial del intento
        data_events_aux = timeLimits.computeTimeLimitEvents(copia,user_objective=[key_split[1]], timeLimit= timestamp[i])

        # recuperamos el historial del usuario
        user_historial = uh.computeUserHistorial(data_events_aux,group = [key_split[0]], user = [key_split[1]])


        # recuperamos elo del jugador y dificultad ELO del puzzle
        print('timestamp:' + str(timestamp[i]))
        totalData = elo.adaptedData(data_events_aux)
        if "user" in totalData.columns:
            user_elo = elo.run(1.8, 0.05, totalData, user_objective =key_split[1], puzzle_objective=key_split[2], group_objective = key_split[0])
        else:
            user_elo = 0
        puzzle_elo = dict_elo_puzzles[key_split[2]]
        print('elo: ' + str(user_elo) + ' puzzle: ' + str(puzzle_elo))


        if(key_split[2] != '' and key_split[1] != '' and i != ''):

            # User, group and puzzle
            activity_by_user.at[i, 'group'] = key_split[0] # Grupo
            activity_by_user.at[i, 'user'] = key_split[1] # Usuario
            activity_by_user.at[i, 'task_id'] = key_split[2] # Puzzle
            activity_by_user.at[i, 'cum_this_puzzle_attempt'] = key_split[3] # Numero de intento de este usuario en este puzzle
            activity_by_user.at[i, 'timestamp'] = timestamp[i] # Timestamp inicial del intento

            # User historial. Percentage of tutorial,intermediate and advanced per puzzle. Attempts per puzzle
            activity_by_user.at[i, 'percentage_tutorial'] = user_historial['percentage_tutorial']
            activity_by_user.at[i, 'percentage_intermediate'] = user_historial['percentage_intermediate']
            activity_by_user.at[i, 'percentage_advanced'] = user_historial['percentage_advanced']
            activity_by_user.at[i, 'attempts_per_puzzle'] = user_historial['attempts_per_puzzle']

            # User and puzzle ELO
            activity_by_user.at[i, 'user_elo'] = user_elo
            activity_by_user.at[i, 'puzzle_elo'] = puzzle_elo

            # Puzzle difficulty
            activity_by_user.at[i, 'puzzle_difficulty'] = round(difficultyPuzzles[key_split[2]],2)

            # features of the attempt
            activity_by_user.at[i, 'n_events'] = puzzleEvents[i] #numero de eventos
            activity_by_user.at[i, 'n_check_solution'] = globalTypesEvents[i]['ws-check_solution'] #numero de submits
            activity_by_user.at[i, 'bestSubmit'] = bestSubmit[i] #numero de submits
            activity_by_user.at[i, 'n_breaks'] = breaksPuzzle[i] #numero de breaks en el intento
            activity_by_user.at[i, 'n_manipulation_events'] = manipulationEvents[i] #numero de intentos de manipulacion
            activity_by_user.at[i, 'n_snapshot'] = globalTypesEvents[i]['ws-snapshot']  #numero de snaphshots
            activity_by_user.at[i, 'n_rotate_view'] = globalTypesEvents[i]['ws-rotate_view'] #numero de rotaciones
            activity_by_user.at[i, 'time_failed_submission_exit'] = timeSubExit[i] #tiempo entre submit y exit
            activity_by_user.at[i, 'avg_time_between_submissions'] = timeBetweenSub[i] #tiempo entre submits

            # label of the attempt
            activity_by_user.at[i, 'completed'] = completados[i] #Ha completado el puzzle o no

        count += 1
        print('Intentos procesados: ', count)

    #delete row with NaN
    activity_by_user.dropna(subset = ['user'], inplace=True)

    #data output preparation
    activity_by_user = pd.DataFrame(activity_by_user, columns=['group', 'user','task_id','cum_this_puzzle_attempt','timestamp','percentage_tutorial','percentage_intermediate','percentage_advanced','attempts_per_puzzle','user_elo','puzzle_elo','puzzle_difficulty','n_events','n_check_solution','bestSubmit','n_breaks','n_manipulation_events','n_snapshot','n_rotate_view','completed'])

    # Crear una instancia del codificador
    encoder = OneHotEncoder()

    # Ajustar el codificador a los datos
    encoder.fit(activity_by_user[['task_id']])

    # Transformar los datos
    encoded_data = encoder.transform(activity_by_user[['task_id']]).toarray()

    # Crear un nuevo DataFrame con los datos codificados
    encoded_df = pd.DataFrame(encoded_data, columns=encoder.categories_[0])

    # Agregar las nuevas columnas al DataFrame original
    activity_by_user = activity_by_user.reset_index(drop=True)
    encoded_df = encoded_df.reset_index(drop=True)
    activity_by_user_encoded = pd.concat([activity_by_user, encoded_df], axis=1)

    return activity_by_user_encoded

# %%
features = computeFeatures(dataEvents,percentil=3)
# Out:
# El proceso 1 tardó 101.9088363647461 segundos.
# timestamp:2019-09-06 15:04:55.942032-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1
# timestamp:2019-09-09 13:29:29.964185-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2
# timestamp:2019-09-09 13:30:02.060673-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  3
# timestamp:2019-09-09 13:31:08.104106-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  4
# timestamp:2019-09-09 13:35:19.373383-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  5
# timestamp:2019-09-09 13:40:23.421491-04:00
# elo: 0.23 puzzle: 0.24
# Intentos procesados:  6
# timestamp:2019-09-09 13:40:32.111635-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  7
# timestamp:2019-09-09 13:40:56.260259-04:00
# elo: 0.23 puzzle: 0.9
# Intentos procesados:  8
# timestamp:2019-09-09 13:43:51.554516-04:00
# elo: 0.23 puzzle: 3.0
# Intentos procesados:  9
# timestamp:2019-09-09 13:44:58.463226-04:00
# elo: 0.23 puzzle: 0.57
# Intentos procesados:  10
# timestamp:2019-09-09 13:48:16.187492-04:00
# elo: 0.23 puzzle: 3.0
# Intentos procesados:  11
# timestamp:2019-09-09 13:57:42.045015-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  12
# timestamp:2019-09-09 13:58:55.405365-04:00
# elo: 0.31 puzzle: 0.57
# Intentos procesados:  13
# timestamp:2019-09-09 14:00:18.912969-04:00
# elo: 0.39 puzzle: 0.57
# Intentos procesados:  14
# timestamp:2019-09-09 14:06:19.293103-04:00
# elo: 0.47 puzzle: 0.99
# Intentos procesados:  15
# timestamp:2019-09-09 14:13:12.491502-04:00
# elo: 0.58 puzzle: 1.77
# Intentos procesados:  16
# timestamp:2019-09-09 14:16:07.487901-04:00
# elo: 0.65 puzzle: 1.26
# Intentos procesados:  17
# timestamp:2019-09-09 14:16:19.943516-04:00
# elo: 0.71 puzzle: 0.78
# Intentos procesados:  18
# timestamp:2019-09-09 14:16:25.811744-04:00
# elo: 0.78 puzzle: 1.29
# Intentos procesados:  19
# timestamp:2019-09-09 14:16:40.587532-04:00
# elo: 0.88 puzzle: 1.91
# Intentos procesados:  20
# timestamp:2019-09-09 14:16:42.954154-04:00
# elo: 0.88 puzzle: 1.29
# Intentos procesados:  21
# timestamp:2019-09-09 14:16:59.408999-04:00
# elo: 0.88 puzzle: 1.91
# Intentos procesados:  22
# timestamp:2019-09-10 13:27:16.295043-04:00
# elo: 0.88 puzzle: 1.91
# Intentos procesados:  23
# timestamp:2019-09-10 13:40:39.894777-04:00
# elo: 1.01 puzzle: 1.62
# Intentos procesados:  24
# timestamp:2019-09-10 13:44:34.784003-04:00
# elo: 1.12 puzzle: 1.62
# Intentos procesados:  25
# timestamp:2019-09-10 13:46:08.981508-04:00
# elo: 1.12 puzzle: 1.74
# Intentos procesados:  26
# timestamp:2019-09-10 13:46:45.283227-04:00
# elo: 1.24 puzzle: 1.35
# Intentos procesados:  27
# timestamp:2019-09-10 13:47:50.161840-04:00
# elo: 1.32 puzzle: 0.9
# Intentos procesados:  28
# timestamp:2019-09-10 13:51:26.018549-04:00
# elo: 1.37 puzzle: 1.7
# Intentos procesados:  29
# timestamp:2019-09-10 13:53:22.263676-04:00
# elo: 1.47 puzzle: 1.73
# Intentos procesados:  30
# timestamp:2019-09-09 13:29:58.878709-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  31
# timestamp:2019-09-09 13:30:32.800475-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  32
# timestamp:2019-09-09 13:31:11.301267-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  33
# timestamp:2019-09-09 13:31:48.114365-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  34
# timestamp:2019-09-09 13:32:28.946061-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  35
# timestamp:2019-09-09 13:39:56.470356-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  36
# timestamp:2019-09-09 13:44:06.913646-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  37
# timestamp:2019-09-09 13:49:09.095690-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  38
# timestamp:2019-09-09 13:50:37.049467-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  39
# timestamp:2019-09-09 13:53:54.864841-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  40
# timestamp:2019-09-09 13:55:38.559441-04:00
# elo: 0.71 puzzle: 3.0
# Intentos procesados:  41
# timestamp:2019-09-09 13:55:54.816700-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  42
# timestamp:2019-09-09 14:07:40.446621-04:00
# elo: 0.8 puzzle: 1.77
# Intentos procesados:  43
# timestamp:2019-09-09 14:10:07.782430-04:00
# elo: 0.87 puzzle: 1.26
# Intentos procesados:  44
# timestamp:2019-09-09 21:04:55.874008-04:00
# elo: 0.92 puzzle: 0.78
# Intentos procesados:  45
# timestamp:2019-09-09 20:58:15.775176-04:00
# elo: 0.92 puzzle: 0.0
# Intentos procesados:  46
# timestamp:2019-09-09 21:01:58.249869-04:00
# elo: 0.92 puzzle: 1.77
# Intentos procesados:  47
# timestamp:2019-09-09 21:03:43.754155-04:00
# elo: 0.92 puzzle: 0.99
# Intentos procesados:  48
# timestamp:2019-09-10 13:33:35.189998-04:00
# elo: 0.97 puzzle: 1.29
# Intentos procesados:  49
# timestamp:2019-09-10 13:34:57.189334-04:00
# elo: 1.07 puzzle: 1.91
# Intentos procesados:  50
# timestamp:2019-09-11 20:46:21.813958-04:00
# elo: 1.07 puzzle: 1.77
# Intentos procesados:  51
# timestamp:2019-11-07 15:11:50.891058-05:00
# elo: 1.07 puzzle: 0.0
# Intentos procesados:  52
# timestamp:2019-11-07 15:12:33.678401-05:00
# elo: 1.07 puzzle: 1.77
# Intentos procesados:  53
# timestamp:2019-09-09 13:30:26.706374-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  54
# timestamp:2019-09-09 13:31:01.219432-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  55
# timestamp:2019-09-09 13:31:56.435671-04:00
# elo: 0.15 puzzle: 0.12
# Intentos procesados:  56
# timestamp:2019-09-09 13:32:53.618827-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  57
# timestamp:2019-09-09 13:33:58.535981-04:00
# elo: 0.23 puzzle: 0.24
# Intentos procesados:  58
# timestamp:2019-09-09 13:34:39.971449-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  59
# timestamp:2019-09-09 13:34:47.721417-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  60
# timestamp:2019-09-09 13:37:35.682346-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  61
# timestamp:2019-09-09 13:38:40.441707-04:00
# elo: 0.4 puzzle: 0.48
# Intentos procesados:  62
# timestamp:2019-09-09 13:43:51.132200-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  63
# timestamp:2019-09-09 13:44:23.397589-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  64
# timestamp:2019-09-09 13:51:04.676590-04:00
# elo: 0.48 puzzle: 0.0
# Intentos procesados:  65
# timestamp:2019-09-09 13:59:59.551560-04:00
# elo: 0.48 puzzle: 0.42
# Intentos procesados:  66
# timestamp:2019-09-09 14:03:26.301570-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  67
# timestamp:2019-09-09 14:04:52.672488-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  68
# timestamp:2019-09-09 14:06:00.855294-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  69
# timestamp:2019-09-10 13:41:17.916542-04:00
# elo: 0.85 puzzle: 0.99
# Intentos procesados:  70
# timestamp:2019-09-10 13:29:27.381725-04:00
# elo: 0.71 puzzle: 1.77
# Intentos procesados:  71
# timestamp:2019-09-10 13:38:11.342204-04:00
# elo: 0.79 puzzle: 1.26
# Intentos procesados:  72
# timestamp:2019-09-10 13:45:05.678145-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  73
# timestamp:2019-09-10 13:48:50.702396-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  74
# timestamp:2019-09-11 13:14:33.360670-04:00
# elo: 1.09 puzzle: 1.91
# Intentos procesados:  75
# timestamp:2019-09-11 13:18:58.052067-04:00
# elo: 1.09 puzzle: 1.62
# Intentos procesados:  76
# timestamp:2019-09-11 13:23:43.777370-04:00
# elo: 1.09 puzzle: 1.74
# Intentos procesados:  77
# timestamp:2019-09-11 13:24:32.209240-04:00
# elo: 1.21 puzzle: 1.35
# Intentos procesados:  78
# timestamp:2019-09-09 13:30:09.830589-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  79
# timestamp:2019-09-09 13:32:13.211155-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  80
# timestamp:2019-09-09 13:33:21.933285-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  81
# timestamp:2019-09-09 13:35:40.719066-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  82
# timestamp:2019-09-09 13:36:51.011987-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  83
# timestamp:2019-09-09 13:50:22.621096-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  84
# timestamp:2019-09-09 13:52:44.555452-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  85
# timestamp:2019-09-09 13:54:49.383312-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  86
# timestamp:2019-09-09 13:57:06.947060-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  87
# timestamp:2019-09-09 14:01:23.527412-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  88
# timestamp:2019-09-09 14:05:16.386318-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  89
# timestamp:2019-09-09 14:07:15.766024-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  90
# timestamp:2019-09-09 14:08:40.199849-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  91
# timestamp:2019-09-09 14:11:21.833465-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  92
# timestamp:2019-09-09 20:21:12.465876-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  93
# timestamp:2019-09-09 20:21:28.198396-04:00
# elo: 1.1 puzzle: 0.48
# Intentos procesados:  94
# timestamp:2019-09-09 20:21:59.473957-04:00
# elo: 1.1 puzzle: 0.0
# Intentos procesados:  95
# timestamp:2019-09-10 13:35:50.685094-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  96
# timestamp:2019-09-10 13:50:44.560274-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  97
# timestamp:2019-09-10 14:00:16.464550-04:00
# elo: 1.34 puzzle: 1.74
# Intentos procesados:  98
# timestamp:2019-11-21 18:39:38.404919-05:00
# elo: 1.34 puzzle: 1.74
# Intentos procesados:  99
# timestamp:2019-09-09 13:31:10.339827-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  100
# timestamp:2019-09-09 13:32:19.452679-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  101
# timestamp:2019-09-09 13:33:31.818274-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  102
# timestamp:2019-09-09 13:36:26.664795-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  103
# timestamp:2019-09-09 13:41:32.529914-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  104
# timestamp:2019-09-09 13:46:56.390427-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  105
# timestamp:2019-09-09 13:55:52.700191-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  106
# timestamp:2019-09-09 13:56:50.128225-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  107
# timestamp:2019-09-10 13:32:58.851250-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  108
# timestamp:2019-09-10 13:36:42.517752-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  109
# timestamp:2019-09-10 13:46:51.277373-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  110
# timestamp:2019-09-10 13:58:34.234719-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  111
# timestamp:2019-09-09 13:30:25.676499-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  112
# timestamp:2019-09-09 13:31:35.914675-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  113
# timestamp:2019-09-09 13:33:09.421680-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  114
# timestamp:2019-09-09 13:34:28.262879-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  115
# timestamp:2019-09-09 13:35:48.326100-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  116
# timestamp:2019-09-09 13:36:37.690907-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  117
# timestamp:2019-09-09 13:38:33.399624-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  118
# timestamp:2019-09-09 13:40:36.826734-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  119
# timestamp:2019-09-09 13:44:11.514549-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  120
# timestamp:2019-09-09 13:47:29.551520-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  121
# timestamp:2019-09-09 13:49:35.524165-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  122
# timestamp:2019-09-09 13:59:49.843810-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  123
# timestamp:2019-09-09 14:01:58.774686-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  124
# timestamp:2019-09-09 14:06:15.750543-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  125
# timestamp:2019-09-09 13:30:37.156578-04:00
# elo: 0 puzzle: 0.78
# Intentos procesados:  126
# timestamp:2019-09-09 13:32:09.335462-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  127
# timestamp:2019-09-09 13:32:42.498852-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  128
# timestamp:2019-09-09 13:34:08.120565-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  129
# timestamp:2019-09-09 13:34:54.930018-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  130
# timestamp:2019-09-09 13:37:28.782667-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  131
# timestamp:2019-09-09 13:50:27.415609-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  132
# timestamp:2019-09-09 13:52:16.395329-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  133
# timestamp:2019-09-09 13:56:10.966634-04:00
# elo: 0.47 puzzle: 0.6
# Intentos procesados:  134
# timestamp:2019-09-09 13:57:48.857481-04:00
# elo: 0.55 puzzle: 0.57
# Intentos procesados:  135
# timestamp:2019-09-09 14:00:23.076101-04:00
# elo: 0.62 puzzle: 0.57
# Intentos procesados:  136
# timestamp:2019-09-10 13:43:09.908815-04:00
# elo: 0.82 puzzle: 0.99
# Intentos procesados:  137
# timestamp:2019-09-10 13:29:24.253548-04:00
# elo: 0.69 puzzle: 1.77
# Intentos procesados:  138
# timestamp:2019-09-10 13:36:41.055090-04:00
# elo: 0.77 puzzle: 1.26
# Intentos procesados:  139
# timestamp:2019-09-11 13:10:18.462479-04:00
# elo: 0.91 puzzle: 0.78
# Intentos procesados:  140
# timestamp:2019-09-11 13:11:52.802418-04:00
# elo: 0.97 puzzle: 1.29
# Intentos procesados:  141
# timestamp:2019-09-11 13:14:33.878543-04:00
# elo: 1.06 puzzle: 1.91
# Intentos procesados:  142
# timestamp:2019-09-11 13:19:02.371270-04:00
# elo: 1.06 puzzle: 1.62
# Intentos procesados:  143
# timestamp:2019-09-11 13:24:28.755723-04:00
# elo: 1.06 puzzle: 1.74
# Intentos procesados:  144
# timestamp:2019-09-11 13:25:17.323951-04:00
# elo: 1.18 puzzle: 1.35
# Intentos procesados:  145
# timestamp:2019-09-11 13:28:01.076527-04:00
# elo: 1.18 puzzle: 1.35
# Intentos procesados:  146
# timestamp:2019-09-11 13:28:25.162685-04:00
# elo: 1.18 puzzle: 0.9
# Intentos procesados:  147
# timestamp:2019-09-09 13:31:00.243114-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  148
# timestamp:2019-09-09 13:32:49.908576-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  149
# timestamp:2019-09-09 13:35:47.894328-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  150
# timestamp:2019-09-09 13:39:01.650789-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  151
# timestamp:2019-09-09 13:41:33.979698-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  152
# timestamp:2019-09-09 13:47:54.570927-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  153
# timestamp:2019-09-09 13:56:16.373639-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  154
# timestamp:2019-09-09 13:58:03.403759-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  155
# timestamp:2019-09-09 14:08:39.756223-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  156
# timestamp:2019-09-10 13:36:37.478237-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  157
# timestamp:2019-09-10 13:44:35.228749-04:00
# elo: 0.81 puzzle: 0.99
# Intentos procesados:  158
# timestamp:2019-09-10 13:47:49.704456-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  159
# timestamp:2019-09-10 13:48:23.820874-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  160
# timestamp:2019-09-10 13:56:26.759278-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  161
# timestamp:2019-09-10 13:59:36.269227-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  162
# timestamp:2019-09-10 14:04:42.913406-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  163
# timestamp:2019-09-09 13:30:53.317062-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  164
# timestamp:2019-09-09 13:31:31.788771-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  165
# timestamp:2019-09-09 13:35:06.369082-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  166
# timestamp:2019-09-09 13:42:27.015243-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  167
# timestamp:2019-09-09 13:49:32.421553-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  168
# timestamp:2019-09-09 13:52:17.609524-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  169
# timestamp:2019-09-09 13:55:29.306566-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  170
# timestamp:2019-09-09 13:56:07.908455-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  171
# timestamp:2019-09-09 14:06:51.620189-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  172
# timestamp:2019-09-09 13:31:00.398570-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  173
# timestamp:2019-09-09 13:32:19.596744-04:00
# elo: 0.08 puzzle: 0.0
# Intentos procesados:  174
# timestamp:2019-09-09 13:32:56.540670-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  175
# timestamp:2019-09-09 13:45:50.416219-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  176
# timestamp:2019-09-09 13:47:38.565223-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  177
# timestamp:2019-09-09 13:50:58.494011-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  178
# timestamp:2019-09-09 13:56:01.305862-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  179
# timestamp:2019-09-09 13:57:51.085499-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  180
# timestamp:2019-09-09 13:30:57.131525-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  181
# timestamp:2019-09-09 13:31:45.358000-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  182
# timestamp:2019-09-09 13:32:57.097795-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  183
# timestamp:2019-09-09 13:33:36.345879-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  184
# timestamp:2019-09-09 13:34:20.031108-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  185
# timestamp:2019-09-09 13:48:38.127614-04:00
# elo: 0.32 puzzle: 0.42
# Intentos procesados:  186
# timestamp:2019-09-09 13:49:30.692585-04:00
# elo: 0.4 puzzle: 0.6
# Intentos procesados:  187
# timestamp:2019-09-09 13:50:18.839541-04:00
# elo: 0.48 puzzle: 0.57
# Intentos procesados:  188
# timestamp:2019-09-09 13:52:55.253287-04:00
# elo: 0.48 puzzle: 0.48
# Intentos procesados:  189
# timestamp:2019-09-09 13:53:32.529880-04:00
# elo: 0.55 puzzle: 0.57
# Intentos procesados:  190
# timestamp:2019-09-09 14:01:59.395170-04:00
# elo: 0.62 puzzle: 0.57
# Intentos procesados:  191
# timestamp:2019-09-09 14:05:41.628815-04:00
# elo: 0.68 puzzle: 0.99
# Intentos procesados:  192
# timestamp:2019-09-09 14:09:29.345803-04:00
# elo: 0.68 puzzle: 1.77
# Intentos procesados:  193
# timestamp:2019-09-09 14:11:44.474095-04:00
# elo: 0.75 puzzle: 1.26
# Intentos procesados:  194
# timestamp:2019-09-10 13:34:08.778721-04:00
# elo: 0.8 puzzle: 1.29
# Intentos procesados:  195
# timestamp:2019-09-10 13:35:35.622777-04:00
# elo: 0.8 puzzle: 1.74
# Intentos procesados:  196
# timestamp:2019-09-10 13:42:36.116253-04:00
# elo: 0.8 puzzle: 1.62
# Intentos procesados:  197
# timestamp:2019-09-10 13:52:16.868515-04:00
# elo: 0.92 puzzle: 1.35
# Intentos procesados:  198
# timestamp:2019-09-11 13:26:02.846606-04:00
# elo: 0.92 puzzle: 0.9
# Intentos procesados:  199
# timestamp:2019-09-09 13:31:18.885447-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  200
# timestamp:2019-09-09 13:32:57.375907-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  201
# timestamp:2019-09-09 13:33:48.930605-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  202
# timestamp:2019-09-09 13:38:38.171808-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  203
# timestamp:2019-09-09 13:41:42.677607-04:00
# elo: 0.23 puzzle: 0.0
# Intentos procesados:  204
# timestamp:2019-09-09 13:56:26.203313-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  205
# timestamp:2019-09-09 13:59:52.805716-04:00
# elo: 0.31 puzzle: 0.48
# Intentos procesados:  206
# timestamp:2019-09-10 13:30:47.063966-04:00
# elo: 0.39 puzzle: 0.42
# Intentos procesados:  207
# timestamp:2019-09-10 13:36:53.988980-04:00
# elo: 0.39 puzzle: 0.57
# Intentos procesados:  208
# timestamp:2019-09-09 13:31:09.375163-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  209
# timestamp:2019-09-09 13:43:26.107130-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  210
# timestamp:2019-09-09 13:44:26.782429-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  211
# timestamp:2019-09-09 13:45:39.666602-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  212
# timestamp:2019-09-09 13:46:27.913221-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  213
# timestamp:2019-09-09 13:49:33.732809-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  214
# timestamp:2019-09-09 13:53:51.513930-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  215
# timestamp:2019-09-09 13:55:05.735246-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  216
# timestamp:2019-09-09 13:58:52.460153-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  217
# timestamp:2019-09-09 14:05:01.418162-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  218
# timestamp:2019-09-09 14:06:10.777246-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  219
# timestamp:2019-09-09 14:09:06.912250-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  220
# timestamp:2019-09-09 14:11:15.470136-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  221
# timestamp:2019-09-09 14:12:47.510397-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  222
# timestamp:2019-09-09 14:14:19.092297-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  223
# timestamp:2019-09-09 13:31:09.524371-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  224
# timestamp:2019-09-09 13:32:48.548713-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  225
# timestamp:2019-09-09 13:34:04.427823-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  226
# timestamp:2019-09-09 13:34:37.947843-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  227
# timestamp:2019-09-09 13:35:41.421070-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  228
# timestamp:2019-09-09 13:38:57.408188-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  229
# timestamp:2019-09-09 13:40:49.392394-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  230
# timestamp:2019-09-09 13:42:16.142702-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  231
# timestamp:2019-09-09 13:43:52.531923-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  232
# timestamp:2019-09-09 13:45:17.224141-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  233
# timestamp:2019-09-09 13:55:58.874011-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  234
# timestamp:2019-09-09 13:57:04.711722-04:00
# elo: 0.8 puzzle: 1.77
# Intentos procesados:  235
# timestamp:2019-09-09 13:58:46.149511-04:00
# elo: 0.87 puzzle: 1.26
# Intentos procesados:  236
# timestamp:2019-09-09 14:00:17.208496-04:00
# elo: 0.92 puzzle: 0.78
# Intentos procesados:  237
# timestamp:2019-09-09 14:02:31.268980-04:00
# elo: 0.98 puzzle: 1.29
# Intentos procesados:  238
# timestamp:2019-09-10 13:28:04.697226-04:00
# elo: 0.98 puzzle: 1.29
# Intentos procesados:  239
# timestamp:2019-09-10 13:34:39.265464-04:00
# elo: 1.08 puzzle: 1.91
# Intentos procesados:  240
# timestamp:2019-09-10 13:39:45.637876-04:00
# elo: 1.2 puzzle: 1.62
# Intentos procesados:  241
# timestamp:2019-09-10 13:41:33.936379-04:00
# elo: 1.31 puzzle: 1.74
# Intentos procesados:  242
# timestamp:2019-09-10 13:42:47.766137-04:00
# elo: 1.42 puzzle: 1.35
# Intentos procesados:  243
# timestamp:2019-09-10 13:45:34.178784-04:00
# elo: 1.5 puzzle: 0.9
# Intentos procesados:  244
# timestamp:2019-09-10 13:46:49.604972-04:00
# elo: 1.55 puzzle: 1.7
# Intentos procesados:  245
# timestamp:2019-09-10 13:52:53.605457-04:00
# elo: 1.64 puzzle: 1.73
# Intentos procesados:  246
# timestamp:2019-09-10 13:58:58.141853-04:00
# elo: 1.73 puzzle: 3.0
# Intentos procesados:  247
# timestamp:2019-09-10 13:59:07.853095-04:00
# elo: 1.73 puzzle: 1.73
# Intentos procesados:  248
# timestamp:2019-09-10 14:05:18.796580-04:00
# elo: 1.82 puzzle: 1.2
# Intentos procesados:  249
# timestamp:2019-09-11 13:06:37.888756-04:00
# elo: 1.82 puzzle: 1.2
# Intentos procesados:  250
# timestamp:2019-09-11 13:07:03.135063-04:00
# elo: 1.82 puzzle: 1.73
# Intentos procesados:  251
# timestamp:2019-09-11 13:07:11.427218-04:00
# elo: 1.82 puzzle: 1.2
# Intentos procesados:  252
# timestamp:2019-09-11 13:22:46.439800-04:00
# elo: 1.87 puzzle: 3.0
# Intentos procesados:  253
# timestamp:2019-09-11 13:33:47.157080-04:00
# elo: 1.87 puzzle: 2.13
# Intentos procesados:  254
# timestamp:2019-09-09 13:31:41.081105-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  255
# timestamp:2019-09-09 13:33:49.071850-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  256
# timestamp:2019-09-09 13:37:05.413927-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  257
# timestamp:2019-09-09 13:38:41.140412-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  258
# timestamp:2019-09-09 13:47:57.756419-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  259
# timestamp:2019-09-09 13:52:21.563461-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  260
# timestamp:2019-09-09 13:55:34.646573-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  261
# timestamp:2019-09-09 13:56:38.975584-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  262
# timestamp:2019-09-09 13:59:33.088688-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  263
# timestamp:2019-09-10 13:28:58.984566-04:00
# elo: 0.71 puzzle: 1.77
# Intentos procesados:  264
# timestamp:2019-09-10 13:37:13.379621-04:00
# elo: 0.79 puzzle: 1.26
# Intentos procesados:  265
# timestamp:2019-09-10 13:39:44.601945-04:00
# elo: 0.85 puzzle: 0.78
# Intentos procesados:  266
# timestamp:2019-09-10 13:52:59.067371-04:00
# elo: 0.91 puzzle: 1.29
# Intentos procesados:  267
# timestamp:2019-09-09 13:31:37.277611-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  268
# timestamp:2019-09-09 13:34:00.213491-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  269
# timestamp:2019-09-09 13:43:58.226281-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  270
# timestamp:2019-09-09 13:47:01.462519-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  271
# timestamp:2019-09-09 13:49:45.753914-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  272
# timestamp:2019-09-09 13:52:54.113674-04:00
# elo: 0.4 puzzle: 0.6
# Intentos procesados:  273
# timestamp:2019-09-09 13:57:24.785931-04:00
# elo: 0.5 puzzle: 0.57
# Intentos procesados:  274
# timestamp:2019-09-09 14:01:49.105782-04:00
# elo: 0.58 puzzle: 0.42
# Intentos procesados:  275
# timestamp:2019-09-09 14:03:01.245894-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  276
# timestamp:2019-09-10 13:36:38.664038-04:00
# elo: 0 puzzle: 0.99
# Intentos procesados:  277
# timestamp:2019-09-10 13:34:15.390007-04:00
# elo: 0 puzzle: 0.99
# Intentos procesados:  278
# timestamp:2019-09-10 13:34:28.263019-04:00
# elo: 0 puzzle: 0.99
# Intentos procesados:  279
# timestamp:2019-09-10 13:34:35.844105-04:00
# elo: 0 puzzle: 1.77
# Intentos procesados:  280
# timestamp:2019-09-10 13:38:33.127529-04:00
# elo: 0 puzzle: 1.26
# Intentos procesados:  281
# timestamp:2019-09-10 13:41:33.505102-04:00
# elo: 0.09 puzzle: 0.78
# Intentos procesados:  282
# timestamp:2019-09-10 13:43:23.769424-04:00
# elo: 0.2 puzzle: 1.29
# Intentos procesados:  283
# timestamp:2019-09-10 13:47:19.696995-04:00
# elo: 0.2 puzzle: 0.0
# Intentos procesados:  284
# timestamp:2019-09-10 13:48:04.944962-04:00
# elo: 0.2 puzzle: 3.0
# Intentos procesados:  285
# timestamp:2019-09-10 13:28:06.876885-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  286
# timestamp:2019-09-10 13:28:35.640441-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  287
# timestamp:2019-09-10 13:30:21.363842-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  288
# timestamp:2019-09-10 13:31:15.378983-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  289
# timestamp:2019-09-10 13:31:52.114504-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  290
# timestamp:2019-09-10 13:33:05.967195-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  291
# timestamp:2019-09-10 13:34:01.538868-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  292
# timestamp:2019-09-10 13:34:39.413956-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  293
# timestamp:2019-09-10 13:35:36.535829-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  294
# timestamp:2019-09-10 13:37:15.283433-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  295
# timestamp:2019-09-10 13:38:14.543487-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  296
# timestamp:2019-09-10 13:41:26.120899-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  297
# timestamp:2019-09-10 13:42:40.132224-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  298
# timestamp:2019-09-10 13:44:07.122043-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  299
# timestamp:2019-09-10 13:45:54.027259-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  300
# timestamp:2019-09-10 13:50:18.355697-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  301
# timestamp:2019-09-10 14:00:17.953325-04:00
# elo: 1.34 puzzle: 1.74
# Intentos procesados:  302
# timestamp:2019-09-10 14:01:10.676539-04:00
# elo: 1.45 puzzle: 1.35
# Intentos procesados:  303
# timestamp:2019-09-10 14:03:24.018252-04:00
# elo: 1.53 puzzle: 0.9
# Intentos procesados:  304
# timestamp:2019-09-10 14:04:59.822931-04:00
# elo: 1.58 puzzle: 1.2
# Intentos procesados:  305
# timestamp:2019-09-09 13:32:14.791766-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  306
# timestamp:2019-09-09 13:33:10.725293-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  307
# timestamp:2019-09-09 13:44:50.258819-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  308
# timestamp:2019-09-09 13:47:37.619250-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  309
# timestamp:2019-09-09 13:54:51.507791-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  310
# timestamp:2019-09-09 13:58:02.693794-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  311
# timestamp:2019-09-09 14:05:37.821698-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  312
# timestamp:2019-09-10 13:32:39.977573-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  313
# timestamp:2019-09-10 13:36:24.519952-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  314
# timestamp:2019-09-10 13:44:15.067059-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  315
# timestamp:2019-09-10 13:53:11.816000-04:00
# elo: 0.81 puzzle: 1.35
# Intentos procesados:  316
# timestamp:2019-09-09 13:32:39.067758-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  317
# timestamp:2019-09-09 13:34:04.867530-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  318
# timestamp:2019-09-09 13:35:59.390496-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  319
# timestamp:2019-09-09 13:37:09.381266-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  320
# timestamp:2019-09-09 13:38:23.530237-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  321
# timestamp:2019-09-09 13:41:35.531420-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  322
# timestamp:2019-09-09 13:45:00.603018-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  323
# timestamp:2019-09-09 13:46:57.391568-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  324
# timestamp:2019-09-09 13:50:11.755389-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  325
# timestamp:2019-09-09 13:55:30.013424-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  326
# timestamp:2019-09-09 14:10:42.934113-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  327
# timestamp:2019-09-09 14:14:25.894018-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  328
# timestamp:2019-09-09 14:15:10.123045-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  329
# timestamp:2019-09-11 13:07:44.904003-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  330
# timestamp:2019-09-11 13:09:47.436893-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  331
# timestamp:2019-09-11 13:11:30.479217-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  332
# timestamp:2019-09-11 13:14:02.389440-04:00
# elo: 1.34 puzzle: 1.74
# Intentos procesados:  333
# timestamp:2019-09-11 13:15:20.355169-04:00
# elo: 1.45 puzzle: 1.35
# Intentos procesados:  334
# timestamp:2019-09-11 13:17:03.816954-04:00
# elo: 1.53 puzzle: 0.9
# Intentos procesados:  335
# timestamp:2019-09-11 13:26:05.492991-04:00
# elo: 1.58 puzzle: 1.7
# Intentos procesados:  336
# timestamp:2019-09-10 13:35:43.766027-04:00
# elo: 0 puzzle: 1.77
# Intentos procesados:  337
# timestamp:2019-09-10 13:53:28.124490-04:00
# elo: 0.12 puzzle: 1.26
# Intentos procesados:  338
# timestamp:2019-09-10 13:58:58.452671-04:00
# elo: 0.2 puzzle: 0.78
# Intentos procesados:  339
# timestamp:2019-09-09 13:32:49.333739-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  340
# timestamp:2019-09-09 13:34:04.283855-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  341
# timestamp:2019-09-09 13:35:17.403614-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  342
# timestamp:2019-09-09 13:37:44.086838-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  343
# timestamp:2019-09-09 13:40:34.676283-04:00
# elo: 0.32 puzzle: 0.9
# Intentos procesados:  344
# timestamp:2019-09-09 13:40:43.432071-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  345
# timestamp:2019-09-09 13:45:13.043374-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  346
# timestamp:2019-09-09 13:47:19.203078-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  347
# timestamp:2019-09-09 13:48:41.511853-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  348
# timestamp:2019-09-09 13:53:12.524751-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  349
# timestamp:2019-09-09 13:56:18.107604-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  350
# timestamp:2019-09-09 14:00:47.865276-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  351
# timestamp:2019-09-09 14:03:22.963583-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  352
# timestamp:2019-09-09 14:06:41.261024-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  353
# timestamp:2019-09-10 13:31:20.251871-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  354
# timestamp:2019-09-10 13:33:25.053017-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  355
# timestamp:2019-09-10 13:44:51.234381-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  356
# timestamp:2019-09-10 13:46:42.193281-04:00
# elo: 1.34 puzzle: 1.74
# Intentos procesados:  357
# timestamp:2019-09-10 13:47:30.807034-04:00
# elo: 1.45 puzzle: 1.35
# Intentos procesados:  358
# timestamp:2019-09-10 13:48:27.617390-04:00
# elo: 1.53 puzzle: 0.9
# Intentos procesados:  359
# timestamp:2019-09-10 13:51:15.555145-04:00
# elo: 1.58 puzzle: 1.7
# Intentos procesados:  360
# timestamp:2019-09-10 13:58:51.025434-04:00
# elo: 1.68 puzzle: 1.73
# Intentos procesados:  361
# timestamp:2019-09-10 14:04:32.217650-04:00
# elo: 1.77 puzzle: 1.73
# Intentos procesados:  362
# timestamp:2019-09-10 13:30:47.731712-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  363
# timestamp:2019-09-10 13:31:24.208795-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  364
# timestamp:2019-09-10 13:32:22.346423-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  365
# timestamp:2019-09-10 13:33:37.335611-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  366
# timestamp:2019-09-10 13:44:31.457726-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  367
# timestamp:2019-09-10 13:45:57.931236-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  368
# timestamp:2019-09-10 13:58:57.264431-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  369
# timestamp:2019-09-10 14:01:35.736421-04:00
# elo: 0.57 puzzle: 0.6
# Intentos procesados:  370
# timestamp:2019-09-10 14:01:39.930280-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  371
# timestamp:2019-09-10 14:09:05.514782-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  372
# timestamp:2019-09-11 13:07:33.436063-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  373
# timestamp:2019-09-10 13:27:34.719737-04:00
# elo: 0 puzzle: 1.91
# Intentos procesados:  374
# timestamp:2019-09-10 13:40:02.862294-04:00
# elo: 0.27 puzzle: 1.62
# Intentos procesados:  375
# timestamp:2019-09-10 13:44:31.888136-04:00
# elo: 0.48 puzzle: 1.74
# Intentos procesados:  376
# timestamp:2019-09-10 13:45:02.552279-04:00
# elo: 0.69 puzzle: 1.35
# Intentos procesados:  377
# timestamp:2019-09-10 13:45:42.136159-04:00
# elo: 0.84 puzzle: 0.9
# Intentos procesados:  378
# timestamp:2019-09-10 13:46:57.998804-04:00
# elo: 0.95 puzzle: 1.7
# Intentos procesados:  379
# timestamp:2019-09-10 13:51:37.122300-04:00
# elo: 1.11 puzzle: 1.73
# Intentos procesados:  380
# timestamp:2019-09-10 13:58:03.173830-04:00
# elo: 1.26 puzzle: 1.73
# Intentos procesados:  381
# timestamp:2019-09-10 14:02:50.250024-04:00
# elo: 1.26 puzzle: 1.2
# Intentos procesados:  382
# timestamp:2019-09-10 14:04:38.435437-04:00
# elo: 1.37 puzzle: 2.13
# Intentos procesados:  383
# timestamp:2019-09-10 14:09:33.190134-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  384
# timestamp:2019-09-10 14:09:56.655033-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  385
# timestamp:2019-09-10 14:10:52.058029-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  386
# timestamp:2019-09-10 14:12:05.101180-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  387
# timestamp:2019-09-09 13:35:22.016445-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  388
# timestamp:2019-09-09 13:35:57.283128-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  389
# timestamp:2019-09-09 13:37:04.700906-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  390
# timestamp:2019-09-09 13:37:52.975539-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  391
# timestamp:2019-09-09 13:38:38.886268-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  392
# timestamp:2019-09-09 13:49:32.710409-04:00
# elo: 0.32 puzzle: 0.42
# Intentos procesados:  393
# timestamp:2019-09-09 13:52:11.906867-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  394
# timestamp:2019-09-09 13:52:43.009110-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  395
# timestamp:2019-09-09 13:56:51.264884-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  396
# timestamp:2019-09-09 13:58:08.607328-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  397
# timestamp:2019-09-09 14:02:18.892242-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  398
# timestamp:2019-09-09 14:05:12.357608-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  399
# timestamp:2019-09-09 16:05:52.427229-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  400
# timestamp:2019-09-10 13:38:37.185832-04:00
# elo: 0.87 puzzle: 1.26
# Intentos procesados:  401
# timestamp:2019-09-10 13:27:21.494232-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  402
# timestamp:2019-09-10 13:40:19.125596-04:00
# elo: 0.93 puzzle: 0.78
# Intentos procesados:  403
# timestamp:2019-09-10 13:42:08.868129-04:00
# elo: 0.93 puzzle: 0.78
# Intentos procesados:  404
# timestamp:2019-09-10 13:47:20.444008-04:00
# elo: 0.99 puzzle: 1.29
# Intentos procesados:  405
# timestamp:2019-09-10 14:08:29.590338-04:00
# elo: 0.99 puzzle: 1.29
# Intentos procesados:  406
# timestamp:2019-09-11 13:11:13.548822-04:00
# elo: 0.99 puzzle: 1.29
# Intentos procesados:  407
# timestamp:2019-09-11 13:22:00.249626-04:00
# elo: 1.07 puzzle: 1.62
# Intentos procesados:  408
# timestamp:2019-09-11 13:24:28.897582-04:00
# elo: 1.07 puzzle: 1.74
# Intentos procesados:  409
# timestamp:2019-09-09 23:43:27.606244-04:00
# elo: 0 puzzle: 0.48
# Intentos procesados:  410
# timestamp:2019-09-10 13:26:24.982371-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  411
# timestamp:2019-09-10 13:27:33.487525-04:00
# elo: 0.08 puzzle: 0.48
# Intentos procesados:  412
# timestamp:2019-09-10 13:30:44.591609-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  413
# timestamp:2019-09-10 13:32:42.314441-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  414
# timestamp:2019-09-10 13:38:55.022052-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  415
# timestamp:2019-09-10 13:40:08.823890-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  416
# timestamp:2019-09-10 13:42:45.409090-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  417
# timestamp:2019-09-10 13:48:02.955124-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  418
# timestamp:2019-09-10 13:56:28.105800-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  419
# timestamp:2019-09-10 14:00:13.133353-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  420
# timestamp:2019-09-10 14:05:40.597951-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  421
# timestamp:2019-09-10 14:14:06.572803-04:00
# elo: 0.71 puzzle: 0.24
# Intentos procesados:  422
# timestamp:2019-09-10 13:32:49.151129-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  423
# timestamp:2019-09-10 13:33:15.812530-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  424
# timestamp:2019-09-10 13:38:26.696495-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  425
# timestamp:2019-09-10 13:39:36.562730-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  426
# timestamp:2019-09-10 13:40:37.931107-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  427
# timestamp:2019-09-10 13:51:06.563991-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  428
# timestamp:2019-09-10 13:55:06.305810-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  429
# timestamp:2019-09-10 13:55:58.904675-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  430
# timestamp:2019-09-10 14:01:10.092235-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  431
# timestamp:2019-09-10 14:03:16.888284-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  432
# timestamp:2019-09-10 14:07:56.105381-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  433
# timestamp:2019-09-10 13:33:55.066568-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  434
# timestamp:2019-09-10 13:35:20.153758-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  435
# timestamp:2019-09-10 13:37:08.550511-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  436
# timestamp:2019-09-10 13:38:31.200406-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  437
# timestamp:2019-09-10 13:46:14.396359-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  438
# timestamp:2019-09-10 13:54:26.890877-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  439
# timestamp:2019-09-10 13:56:55.936394-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  440
# timestamp:2019-09-13 11:55:15.042025-04:00
# elo: 0 puzzle: 0.6
# Intentos procesados:  441
# timestamp:2019-09-13 11:55:31.914354-04:00
# elo: 0 puzzle: 0.99
# Intentos procesados:  442
# timestamp:2019-09-13 11:57:54.173617-04:00
# elo: 0.16 puzzle: 1.77
# Intentos procesados:  443
# timestamp:2019-09-13 12:03:16.876502-04:00
# elo: 0.27 puzzle: 1.26
# Intentos procesados:  444
# timestamp:2019-09-13 12:04:40.838814-04:00
# elo: 0.35 puzzle: 0.78
# Intentos procesados:  445
# timestamp:2019-09-13 12:06:49.500650-04:00
# elo: 0.45 puzzle: 1.29
# Intentos procesados:  446
# timestamp:2019-09-13 12:09:28.560575-04:00
# elo: 0.45 puzzle: 1.91
# Intentos procesados:  447
# timestamp:2019-09-13 12:11:02.263769-04:00
# elo: 0.45 puzzle: 1.91
# Intentos procesados:  448
# timestamp:2019-09-13 12:15:07.252108-04:00
# elo: 0.62 puzzle: 1.62
# Intentos procesados:  449
# timestamp:2019-09-13 12:15:45.922981-04:00
# elo: 0.78 puzzle: 0.6
# Intentos procesados:  450
# timestamp:2019-09-13 12:16:54.794255-04:00
# elo: 0.85 puzzle: 1.35
# Intentos procesados:  451
# timestamp:2019-09-13 12:18:12.480029-04:00
# elo: 0.97 puzzle: 1.29
# Intentos procesados:  452
# timestamp:2019-09-13 12:18:20.299654-04:00
# elo: 0.97 puzzle: 0.42
# Intentos procesados:  453
# timestamp:2019-09-13 12:18:51.269953-04:00
# elo: 1.03 puzzle: 0.6
# Intentos procesados:  454
# timestamp:2019-09-13 12:19:11.647891-04:00
# elo: 1.09 puzzle: 1.29
# Intentos procesados:  455
# timestamp:2019-09-13 12:28:15.752016-04:00
# elo: 1.09 puzzle: 0.9
# Intentos procesados:  456
# timestamp:2019-09-13 12:28:49.496560-04:00
# elo: 1.16 puzzle: 1.7
# Intentos procesados:  457
# timestamp:2019-09-13 12:30:18.894725-04:00
# elo: 1.28 puzzle: 1.73
# Intentos procesados:  458
# timestamp:2019-09-13 12:31:57.990285-04:00
# elo: 1.39 puzzle: 1.73
# Intentos procesados:  459
# timestamp:2019-09-13 12:34:08.350199-04:00
# elo: 1.5 puzzle: 1.2
# Intentos procesados:  460
# timestamp:2019-09-13 12:37:34.950974-04:00
# elo: 1.57 puzzle: 2.13
# Intentos procesados:  461
# timestamp:2019-09-13 12:43:29.057489-04:00
# elo: 1.57 puzzle: 1.74
# Intentos procesados:  462
# timestamp:2019-09-13 12:43:33.522648-04:00
# elo: 1.57 puzzle: 1.74
# Intentos procesados:  463
# timestamp:2019-09-12 14:53:21.078104-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  464
# timestamp:2019-09-12 14:53:44.522499-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  465
# timestamp:2019-09-12 14:56:58.321442-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  466
# timestamp:2019-09-12 14:58:32.149613-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  467
# timestamp:2019-09-13 11:57:23.596558-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  468
# timestamp:2019-09-13 12:00:24.588572-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  469
# timestamp:2019-09-13 12:04:03.463402-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  470
# timestamp:2019-09-13 12:04:49.271124-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  471
# timestamp:2019-09-12 14:53:40.360656-04:00
# elo: 0 puzzle: 0.12
# Intentos procesados:  472
# timestamp:2019-09-12 14:56:41.492652-04:00
# elo: 0.08 puzzle: 0.0
# Intentos procesados:  473
# timestamp:2019-09-12 14:57:06.900616-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  474
# timestamp:2019-09-12 14:57:52.742983-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  475
# timestamp:2019-09-12 14:58:32.722583-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  476
# timestamp:2019-09-12 14:59:32.048720-04:00
# elo: 0.41 puzzle: 0.42
# Intentos procesados:  477
# timestamp:2019-09-12 15:01:13.162141-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  478
# timestamp:2019-09-12 15:03:46.405042-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  479
# timestamp:2019-09-12 15:05:03.704687-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  480
# timestamp:2019-09-13 11:54:57.120858-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  481
# timestamp:2019-09-13 11:59:04.835022-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  482
# timestamp:2019-09-13 12:01:25.983148-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  483
# timestamp:2019-09-13 12:08:14.273464-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  484
# timestamp:2019-09-13 12:09:43.721880-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  485
# timestamp:2019-09-13 12:10:58.231733-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  486
# timestamp:2019-09-13 12:21:52.192624-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  487
# timestamp:2019-09-13 12:22:42.569867-04:00
# elo: 1.34 puzzle: 0.6
# Intentos procesados:  488
# timestamp:2019-09-13 12:24:06.962240-04:00
# elo: 1.38 puzzle: 1.35
# Intentos procesados:  489
# timestamp:2019-09-13 12:25:39.617967-04:00
# elo: 1.47 puzzle: 0.9
# Intentos procesados:  490
# timestamp:2019-09-13 12:26:12.778800-04:00
# elo: 1.52 puzzle: 1.7
# Intentos procesados:  491
# timestamp:2019-09-13 12:30:12.576701-04:00
# elo: 1.62 puzzle: 1.73
# Intentos procesados:  492
# timestamp:2019-09-13 12:31:48.475777-04:00
# elo: 1.71 puzzle: 1.73
# Intentos procesados:  493
# timestamp:2019-09-13 12:34:52.009084-04:00
# elo: 1.8 puzzle: 1.2
# Intentos procesados:  494
# timestamp:2019-09-13 12:38:06.395230-04:00
# elo: 1.85 puzzle: 2.13
# Intentos procesados:  495
# timestamp:2019-09-13 12:38:50.659597-04:00
# elo: 1.96 puzzle: 1.74
# Intentos procesados:  496
# timestamp:2019-09-13 12:43:20.081388-04:00
# elo: 2.04 puzzle: 1.81
# Intentos procesados:  497
# timestamp:2019-09-18 12:50:24.060563-04:00
# elo: 2.12 puzzle: 2.98
# Intentos procesados:  498
# timestamp:2019-09-18 12:50:11.930763-04:00
# elo: 2.12 puzzle: 1.73
# Intentos procesados:  499
# timestamp:2019-09-20 12:11:36.764150-04:00
# elo: 2.19 puzzle: 1.93
# Intentos procesados:  500
# timestamp:2019-09-12 14:53:29.913422-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  501
# timestamp:2019-09-12 14:54:11.069641-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  502
# timestamp:2019-09-12 14:56:20.265295-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  503
# timestamp:2019-09-12 14:58:49.037274-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  504
# timestamp:2019-09-12 15:02:42.724606-04:00
# elo: 0.23 puzzle: 0.48
# Intentos procesados:  505
# timestamp:2019-09-12 15:07:19.866856-04:00
# elo: 0.32 puzzle: 0.42
# Intentos procesados:  506
# timestamp:2019-09-12 15:09:03.770487-04:00
# elo: 0.4 puzzle: 0.6
# Intentos procesados:  507
# timestamp:2019-09-12 15:11:00.543704-04:00
# elo: 0.49 puzzle: 0.57
# Intentos procesados:  508
# timestamp:2019-09-12 15:11:49.740135-04:00
# elo: 0.56 puzzle: 0.57
# Intentos procesados:  509
# timestamp:2019-09-13 11:56:23.656668-04:00
# elo: 0.56 puzzle: 0.57
# Intentos procesados:  510
# timestamp:2019-09-13 11:58:37.450042-04:00
# elo: 0.63 puzzle: 0.42
# Intentos procesados:  511
# timestamp:2019-09-13 11:59:17.988731-04:00
# elo: 0.68 puzzle: 0.99
# Intentos procesados:  512
# timestamp:2019-09-13 12:14:19.093906-04:00
# elo: 0.68 puzzle: 1.77
# Intentos procesados:  513
# timestamp:2019-09-13 12:19:31.909195-04:00
# elo: 0.75 puzzle: 1.26
# Intentos procesados:  514
# timestamp:2019-09-12 14:53:27.535431-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  515
# timestamp:2019-09-12 14:54:24.007159-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  516
# timestamp:2019-09-12 14:55:20.241956-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  517
# timestamp:2019-09-12 14:56:27.799584-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  518
# timestamp:2019-09-12 14:58:07.020368-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  519
# timestamp:2019-09-12 14:58:57.476074-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  520
# timestamp:2019-09-12 15:01:09.103891-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  521
# timestamp:2019-09-12 15:06:47.445300-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  522
# timestamp:2019-09-12 15:07:44.562179-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  523
# timestamp:2019-09-12 15:09:42.311997-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  524
# timestamp:2019-09-13 11:56:36.221702-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  525
# timestamp:2019-09-13 11:57:51.517624-04:00
# ...
# timestamp:2019-09-26 15:54:48.477923-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1965
# timestamp:2019-09-26 15:57:40.845055-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1966
# timestamp:2019-09-26 15:59:04.294553-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  1967
# timestamp:2019-09-26 15:55:25.938785-04:00
# elo: 0 puzzle: 0.99
# Intentos procesados:  1968
# timestamp:2019-09-26 15:57:08.636744-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1969
# timestamp:2019-09-26 15:57:34.967705-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1970
# timestamp:2019-09-26 15:58:56.287176-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1971
# timestamp:2019-09-26 15:59:40.058714-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  1972
# timestamp:2019-09-26 16:00:18.246805-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  1973
# timestamp:2019-09-26 16:05:05.674903-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  1974
# timestamp:2019-09-26 16:06:35.089903-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  1975
# timestamp:2019-09-26 15:56:20.355512-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1976
# timestamp:2019-09-26 15:58:21.011667-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1977
# timestamp:2019-09-26 16:00:34.797998-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1978
# timestamp:2019-09-26 16:05:19.121714-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  1979
# timestamp:2019-09-26 15:56:20.816474-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1980
# timestamp:2019-09-26 15:56:44.443817-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1981
# timestamp:2019-09-26 15:57:17.374801-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1982
# timestamp:2019-09-26 16:00:17.557910-04:00
# elo: 0.15 puzzle: 3.0
# Intentos procesados:  1983
# timestamp:2019-09-26 16:01:10.036598-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1984
# timestamp:2019-09-26 16:04:05.574551-04:00
# elo: 0.22 puzzle: 0.42
# Intentos procesados:  1985
# timestamp:2019-09-26 16:00:12.024082-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1986
# timestamp:2019-09-26 16:02:03.658914-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1987
# timestamp:2019-09-26 16:03:15.541536-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1988
# timestamp:2019-09-26 16:02:08.147102-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1989
# timestamp:2019-09-26 16:02:32.626103-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1990
# timestamp:2019-09-26 16:03:40.209668-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1991
# timestamp:2019-09-26 16:06:03.891500-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  1992
# timestamp:2019-10-18 11:46:24.920705-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  1993
# timestamp:2019-10-18 11:46:37.684846-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  1994
# timestamp:2019-10-18 11:46:57.498440-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  1995
# timestamp:2019-10-18 11:47:28.727295-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  1996
# timestamp:2019-10-18 11:48:02.015188-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  1997
# timestamp:2019-10-18 11:50:13.203990-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  1998
# timestamp:2019-10-18 11:50:39.813081-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  1999
# timestamp:2019-10-18 11:51:41.566985-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  2000
# timestamp:2019-10-18 11:52:31.946714-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  2001
# timestamp:2019-10-18 11:54:13.164882-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  2002
# timestamp:2019-10-18 11:56:51.292577-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  2003
# timestamp:2019-10-18 12:02:15.447307-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  2004
# timestamp:2019-10-18 12:03:49.751495-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  2005
# timestamp:2019-10-18 12:04:39.185731-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  2006
# timestamp:2019-10-18 12:08:51.132438-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  2007
# timestamp:2019-10-18 12:14:15.992336-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  2008
# timestamp:2019-10-18 12:18:27.792769-04:00
# elo: 1.34 puzzle: 0.6
# Intentos procesados:  2009
# timestamp:2019-10-18 12:19:08.988389-04:00
# elo: 1.38 puzzle: 1.35
# Intentos procesados:  2010
# timestamp:2019-10-18 12:19:43.349243-04:00
# elo: 1.47 puzzle: 0.9
# Intentos procesados:  2011
# timestamp:2019-10-18 12:20:26.210304-04:00
# elo: 1.52 puzzle: 1.7
# Intentos procesados:  2012
# timestamp:2019-10-23 10:05:08.080150-04:00
# elo: 1.62 puzzle: 1.73
# Intentos procesados:  2013
# timestamp:2019-10-23 10:05:30.632684-04:00
# elo: 1.62 puzzle: 1.2
# Intentos procesados:  2014
# timestamp:2019-10-23 10:05:40.301219-04:00
# elo: 1.62 puzzle: 3.0
# Intentos procesados:  2015
# timestamp:2019-10-23 10:05:54.850432-04:00
# elo: 1.62 puzzle: 1.29
# Intentos procesados:  2016
# timestamp:2019-10-23 10:11:48.747695-04:00
# elo: 1.62 puzzle: 1.73
# Intentos procesados:  2017
# timestamp:2019-10-23 10:25:16.500658-04:00
# elo: 1.71 puzzle: 1.73
# Intentos procesados:  2018
# timestamp:2019-10-24 12:59:55.940601-04:00
# elo: 1.8 puzzle: 1.2
# Intentos procesados:  2019
# timestamp:2019-10-24 13:03:47.080077-04:00
# elo: 1.85 puzzle: 1.73
# Intentos procesados:  2020
# timestamp:2019-10-24 13:03:57.188630-04:00
# elo: 1.85 puzzle: 2.13
# Intentos procesados:  2021
# timestamp:2019-10-24 13:05:40.794588-04:00
# elo: 1.96 puzzle: 1.74
# Intentos procesados:  2022
# timestamp:2019-10-24 13:08:02.067543-04:00
# elo: 2.04 puzzle: 1.81
# Intentos procesados:  2023
# timestamp:2019-10-18 11:47:42.975428-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2024
# timestamp:2019-10-18 11:49:23.467071-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  2025
# timestamp:2019-10-18 11:50:03.718964-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2026
# timestamp:2019-10-18 11:51:15.336852-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  2027
# timestamp:2019-10-18 11:51:39.262648-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2028
# timestamp:2019-10-18 11:58:48.391914-04:00
# elo: 0.32 puzzle: 0.42
# Intentos procesados:  2029
# timestamp:2019-10-18 11:59:11.198382-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2030
# timestamp:2019-10-18 11:59:41.808407-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  2031
# timestamp:2019-10-18 12:00:35.391009-04:00
# elo: 0.47 puzzle: 0.6
# Intentos procesados:  2032
# timestamp:2019-10-18 12:00:59.547200-04:00
# elo: 0.55 puzzle: 0.57
# Intentos procesados:  2033
# timestamp:2019-10-24 12:58:54.090760-04:00
# elo: 0.62 puzzle: 0.57
# Intentos procesados:  2034
# timestamp:2019-10-18 11:49:30.036850-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2035
# timestamp:2019-10-18 11:50:27.359198-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  2036
# timestamp:2019-10-18 11:57:46.048282-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2037
# timestamp:2019-10-18 11:58:08.788828-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  2038
# timestamp:2019-10-18 11:58:32.887759-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2039
# timestamp:2019-10-18 12:02:36.203628-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  2040
# timestamp:2019-10-18 12:04:14.723352-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  2041
# timestamp:2019-10-18 12:04:35.782463-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  2042
# timestamp:2019-10-18 12:05:28.238702-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  2043
# timestamp:2019-10-18 12:08:54.836211-04:00
# elo: 0.71 puzzle: 0.0
# Intentos procesados:  2044
# timestamp:2019-10-18 12:12:03.698118-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  2045
# timestamp:2019-10-18 12:12:50.728171-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  2046
# timestamp:2019-10-18 12:17:47.872397-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  2047
# timestamp:2019-10-18 12:18:56.747923-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  2048
# timestamp:2019-10-18 12:21:16.409364-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  2049
# timestamp:2019-10-23 10:12:10.644692-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  2050
# timestamp:2019-10-23 10:19:39.725472-04:00
# elo: 1.1 puzzle: 1.62
# Intentos procesados:  2051
# timestamp:2019-10-23 10:19:49.362199-04:00
# elo: 1.1 puzzle: 1.62
# Intentos procesados:  2052
# timestamp:2019-10-24 13:29:14.342489-04:00
# elo: 1.21 puzzle: 2.98
# Intentos procesados:  2053
# timestamp:2019-10-24 13:32:40.229131-04:00
# elo: 1.21 puzzle: 0.0
# Intentos procesados:  2054
# timestamp:2019-10-24 13:33:37.863981-04:00
# elo: 1.21 puzzle: 0.9
# Intentos procesados:  2055
# timestamp:2019-10-18 11:49:05.556184-04:00
# elo: 0 puzzle: 0.9
# Intentos procesados:  2056
# timestamp:2019-10-18 11:50:55.059454-04:00
# elo: 0.0 puzzle: 0.0
# Intentos procesados:  2057
# timestamp:2019-10-18 11:51:15.777747-04:00
# elo: 0.07 puzzle: 0.12
# Intentos procesados:  2058
# timestamp:2019-10-18 11:52:17.790992-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2059
# timestamp:2019-10-18 11:52:40.014725-04:00
# elo: 0.22 puzzle: 0.42
# Intentos procesados:  2060
# timestamp:2019-10-18 11:54:00.774701-04:00
# elo: 0.31 puzzle: 0.48
# Intentos procesados:  2061
# timestamp:2019-10-18 11:54:40.474064-04:00
# elo: 0.39 puzzle: 0.42
# Intentos procesados:  2062
# timestamp:2019-10-18 11:56:13.871055-04:00
# elo: 0.46 puzzle: 0.6
# Intentos procesados:  2063
# timestamp:2019-10-18 11:58:42.400161-04:00
# elo: 0.55 puzzle: 0.57
# Intentos procesados:  2064
# timestamp:2019-10-18 12:00:11.981040-04:00
# elo: 0.62 puzzle: 0.57
# Intentos procesados:  2065
# timestamp:2019-10-18 12:01:50.698289-04:00
# elo: 0.69 puzzle: 0.99
# Intentos procesados:  2066
# timestamp:2019-10-18 12:02:36.054568-04:00
# elo: 0.78 puzzle: 1.77
# Intentos procesados:  2067
# timestamp:2019-10-18 12:03:29.202549-04:00
# elo: 0.85 puzzle: 1.26
# Intentos procesados:  2068
# timestamp:2019-10-18 12:07:46.978026-04:00
# elo: 0.85 puzzle: 0.78
# Intentos procesados:  2069
# timestamp:2019-10-18 12:09:28.115224-04:00
# elo: 0.91 puzzle: 1.29
# Intentos procesados:  2070
# timestamp:2019-10-18 12:14:05.966439-04:00
# elo: 0.91 puzzle: 1.91
# Intentos procesados:  2071
# timestamp:2019-10-18 12:15:46.961720-04:00
# elo: 0.91 puzzle: 1.62
# Intentos procesados:  2072
# timestamp:2019-10-18 12:17:32.590411-04:00
# elo: 0.91 puzzle: 0.6
# Intentos procesados:  2073
# timestamp:2019-10-18 12:18:06.844861-04:00
# elo: 0.97 puzzle: 1.35
# Intentos procesados:  2074
# timestamp:2019-10-18 12:18:48.141441-04:00
# elo: 1.05 puzzle: 0.9
# Intentos procesados:  2075
# timestamp:2019-10-18 12:20:46.235980-04:00
# elo: 1.11 puzzle: 1.7
# Intentos procesados:  2076
# timestamp:2019-10-18 12:22:46.756315-04:00
# elo: 1.11 puzzle: 1.73
# Intentos procesados:  2077
# timestamp:2019-10-18 12:22:52.377742-04:00
# elo: 1.11 puzzle: 1.7
# Intentos procesados:  2078
# timestamp:2019-10-18 12:24:32.932546-04:00
# elo: 1.11 puzzle: 1.73
# Intentos procesados:  2079
# timestamp:2019-10-18 12:25:49.276337-04:00
# elo: 1.11 puzzle: 0.0
# Intentos procesados:  2080
# timestamp:2019-10-24 12:59:30.920943-04:00
# elo: 1.11 puzzle: 2.37
# Intentos procesados:  2081
# timestamp:2019-10-24 13:00:01.563638-04:00
# elo: 1.11 puzzle: 2.13
# Intentos procesados:  2082
# timestamp:2019-10-24 13:01:27.130073-04:00
# elo: 1.23 puzzle: 1.74
# Intentos procesados:  2083
# timestamp:2019-10-24 13:03:28.884817-04:00
# elo: 1.32 puzzle: 1.81
# Intentos procesados:  2084
# timestamp:2019-10-24 13:07:23.412844-04:00
# elo: 1.32 puzzle: 2.98
# Intentos procesados:  2085
# timestamp:2019-10-24 13:09:37.480611-04:00
# elo: 1.32 puzzle: 1.81
# Intentos procesados:  2086
# timestamp:2019-10-24 13:10:17.167510-04:00
# elo: 1.32 puzzle: 3.0
# Intentos procesados:  2087
# timestamp:2019-10-24 13:19:05.584379-04:00
# elo: 1.32 puzzle: 1.93
# Intentos procesados:  2088
# timestamp:2019-10-24 13:19:13.450260-04:00
# elo: 1.32 puzzle: 2.37
# Intentos procesados:  2089
# timestamp:2019-10-24 13:25:34.439649-04:00
# elo: 1.32 puzzle: 0.0
# Intentos procesados:  2090
# timestamp:2019-10-18 11:49:28.086264-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2091
# timestamp:2019-10-18 11:50:12.791726-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  2092
# timestamp:2019-10-18 11:50:57.877966-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2093
# timestamp:2019-10-18 11:52:26.894774-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  2094
# timestamp:2019-10-18 11:54:17.062295-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2095
# timestamp:2019-10-18 12:00:11.128692-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  2096
# timestamp:2019-10-18 12:01:09.516743-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  2097
# timestamp:2019-10-23 10:09:15.191082-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  2098
# timestamp:2019-10-23 10:13:36.326573-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  2099
# timestamp:2019-10-18 11:50:19.891044-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2100
# timestamp:2019-10-18 11:51:22.420307-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  2101
# timestamp:2019-10-18 11:54:56.700784-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2102
# timestamp:2019-10-18 11:57:48.465584-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  2103
# timestamp:2019-10-18 12:01:44.270184-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2104
# timestamp:2019-10-18 12:03:24.202539-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  2105
# timestamp:2019-10-18 12:04:24.532287-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  2106
# timestamp:2019-10-18 12:04:50.113560-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  2107
# timestamp:2019-10-18 12:11:52.485453-04:00
# elo: 0.57 puzzle: 0.57
# Intentos procesados:  2108
# timestamp:2019-10-18 12:12:32.253697-04:00
# elo: 0.64 puzzle: 0.57
# Intentos procesados:  2109
# timestamp:2019-10-18 12:13:29.969351-04:00
# elo: 0.71 puzzle: 0.0
# Intentos procesados:  2110
# timestamp:2019-10-18 12:15:12.936455-04:00
# elo: 0.71 puzzle: 0.99
# Intentos procesados:  2111
# timestamp:2019-10-18 12:17:12.564596-04:00
# elo: 0.81 puzzle: 1.77
# Intentos procesados:  2112
# timestamp:2019-10-18 12:20:28.807846-04:00
# elo: 0.88 puzzle: 1.26
# Intentos procesados:  2113
# timestamp:2019-10-18 12:21:26.386059-04:00
# elo: 0.94 puzzle: 0.78
# Intentos procesados:  2114
# timestamp:2019-10-18 12:26:49.255055-04:00
# elo: 1.0 puzzle: 1.29
# Intentos procesados:  2115
# timestamp:2019-10-23 10:07:55.732349-04:00
# elo: 1.1 puzzle: 1.91
# Intentos procesados:  2116
# timestamp:2019-10-23 10:19:35.037631-04:00
# elo: 1.23 puzzle: 1.26
# Intentos procesados:  2117
# timestamp:2019-10-23 10:21:33.066597-04:00
# elo: 1.23 puzzle: 1.62
# Intentos procesados:  2118
# timestamp:2019-10-23 10:26:40.571954-04:00
# elo: 1.34 puzzle: 0.6
# Intentos procesados:  2119
# timestamp:2019-10-23 10:27:23.297262-04:00
# elo: 1.38 puzzle: 1.35
# Intentos procesados:  2120
# timestamp:2019-10-24 13:01:22.239696-04:00
# elo: 1.56 puzzle: 0.9
# Intentos procesados:  2121
# timestamp:2019-10-24 12:57:29.061971-04:00
# elo: 1.47 puzzle: 1.7
# Intentos procesados:  2122
# timestamp:2019-10-24 13:02:05.523165-04:00
# elo: 1.62 puzzle: 1.73
# Intentos procesados:  2123
# timestamp:2019-10-24 13:07:13.952820-04:00
# elo: 1.71 puzzle: 1.73
# Intentos procesados:  2124
# timestamp:2019-10-24 13:24:28.845276-04:00
# elo: 1.8 puzzle: 1.2
# Intentos procesados:  2125
# timestamp:2019-10-24 13:25:46.713824-04:00
# elo: 1.86 puzzle: 2.13
# Intentos procesados:  2126
# timestamp:2019-10-24 13:28:15.509381-04:00
# elo: 1.96 puzzle: 1.74
# Intentos procesados:  2127
# timestamp:2019-10-24 13:32:19.505400-04:00
# elo: 1.96 puzzle: 1.74
# Intentos procesados:  2128
# timestamp:2019-10-24 13:33:28.905200-04:00
# elo: 1.96 puzzle: 0.0
# Intentos procesados:  2129
# timestamp:2019-10-18 11:50:33.433824-04:00
# elo: 0 puzzle: 0.9
# Intentos procesados:  2130
# timestamp:2019-10-18 11:51:38.678145-04:00
# elo: 0 puzzle: 0.0
# Intentos procesados:  2131
# timestamp:2019-10-18 11:51:57.446706-04:00
# elo: 0.08 puzzle: 0.12
# Intentos procesados:  2132
# timestamp:2019-10-18 11:52:35.887180-04:00
# elo: 0.15 puzzle: 0.24
# Intentos procesados:  2133
# timestamp:2019-10-18 11:53:33.478681-04:00
# elo: 0.23 puzzle: 0.42
# Intentos procesados:  2134
# timestamp:2019-10-18 11:54:04.619870-04:00
# elo: 0.32 puzzle: 0.48
# Intentos procesados:  2135
# timestamp:2019-10-18 11:55:12.478263-04:00
# elo: 0.4 puzzle: 0.42
# Intentos procesados:  2136
# timestamp:2019-10-18 11:57:25.011998-04:00
# elo: 0.48 puzzle: 0.6
# Intentos procesados:  2137

# %%
features.to_csv("../Outputs/featuresOutput3.csv", decimal=".", sep=";", mode='w')
